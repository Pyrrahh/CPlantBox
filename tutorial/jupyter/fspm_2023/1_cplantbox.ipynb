# %%
import os

#is the notebook running on Colab?
try:
    os.environ['COLAB_JUPYTER_TRANSPORT']
    isColab = True
except:
    isColab = False
    
if isColab:
    # downloading the source code
    ! git clone https://github.com/Plant-Root-Soil-Interactions-Modelling/CPlantBox --depth=1 --single-branch -b fspm2023
    os.chdir("/content/CPlantBox/")
    # !apt install libeigen3-dev
    ! apt install llvm-dev
    # !pip3 install vtk
    # !sudo DEBIAN_FRONTEND=noninteractive apt-get install -yq xvfb
    # !pip install -q 'xvfbwrapper~=0.2.9'
    if 'vdisplay' not in globals():
        # start a virtual X display for MAGICAL rendering
        import xvfbwrapper
        vdisplay = xvfbwrapper.Xvfb()
        vdisplay.start()
    os.environ["CUDA_VISIBLE_DEVICES"] = "1"
    ! git pull
    ! cmake .
    ! make
    os.chdir("/content/CPlantBox/tutorial/jupyter/fspm_2023/")

# %% [markdown]
# # FSPM - 2023

# %%
import sys; sys.path.append("../../.."); sys.path.append("../../../src")
import importlib
import plantbox as pb
import visualisation.vtk_plot
importlib.reload(visualisation.vtk_plot)
import visualisation.vtk_plot as vp # for quick 3d vizualisations
import matplotlib.pyplot as plt # for 2d plots
import numpy as np

# %% [markdown]
# ## 1. Simulate a root system

# %%
# Create instance describing a root system
rs = pb.RootSystem()

# Open plant and root parameter from a file
path = "../../../modelparameter/structural/rootsystem/"
name = "Anagallis_femina_Leitner_2010"
rs.readParameters(path + name + ".xml")

# Simulate
rs.initialize() 
rs.simulate(30) # [days]

# Export
rs.write("first_example.vtp") # for Paraview
rs.write("first_example.rsml") # e.g. gui/viewer/rsml_viewer.py

# Visualize
#print(rs, "creationTime",not isColab)
_ = vp.plot_roots(rs, "creationTime", interactiveImage = not isColab) # Plot, using vtk (e.g. "subType")

# %% [markdown]
# ## 2. Post-processing (how to evaluate simulation results)
#
# Basically, there are two methods
#
# 1. Using class *RootSystem* directly, parameter values are given per root (root system is represented as polylines).
#
# 2. Using class *SegmentAnalyser*, which will consider all segments of the root system, parameter values are given per segment (root system is represented by nodes and segments).

# %% [markdown]
# ### 2.1 Root system length vs time

# %% [markdown]
# A typical simulation loop will look like

# %%
rs = pb.RootSystem()
path = "../../../modelparameter/structural/rootsystem/"
name = "Zea_mays_1_Leitner_2010"
rs.readParameters(path + name + ".xml")
rs.setGeometry(pb.SDF_PlantBox(1.e6,1.e6,1.e6)) 
rs.initialize()

""" Simulation loop """
simtime = 60.  # final simulation time [day]
dt = 1. # time step [day]
N = round(simtime / dt)  # number of iterations

for i in range(0, N):
    
    # Coupling to plant functional models or soil     
    
    rs.simulate(dt)
    
    # Coupling to plant functional models or soil 
    
    # Code for post-processing per time step (e.g. store relevant information in a list)
    

# Code for post-processing of the final result (write relevant results, e.g. csv, xls, etc.)
_  = vp.plot_roots(rs, "subType",interactiveImage = not isColab) # Plot, using vtk
# Out:
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml
# Seed::initialize: RootSystem
# Seed::initialize: Basal root type #4 was not defined, using tap root parameters instead

# %% [markdown]
# The following example will plot length versus time for the root system, and each subType (see *example2d_length.py*

# %%
rs.initialize() # reset above simulation
scalar_type = "length" # "surface", "volume"
v_, v1_, v2_, v3_, v4_ = np.zeros(N), np.zeros(N), np.zeros(N), np.zeros(N), np.zeros(N)

""" Simulation loop """
for i in range(0, N):
    rs.simulate(dt)
    t = np.array(rs.getParameter("subType")) # value per root
    v = np.array(rs.getParameter(scalar_type)) # all random or specific parameters are accessible
    v_[i] = np.sum(v)
    v1_[i] = np.sum(v[t == 1])
    v2_[i] = np.sum(v[t == 2])
    v3_[i] = np.sum(v[t == 3])
    v4_[i] = np.sum(v[t == 4])
    
t_ = np.linspace(dt, N * dt, N)
plt.plot(t_, v_, t_, v1_, t_, v2_, t_, v3_, t_, v4_)
plt.xlabel("time (days)")
plt.ylabel(scalar_type + " (cm)")
plt.legend(["total", "tap root", "lateral", "2nd order lateral", "basal roots"])
# plt.savefig("myplot.png") # we could save it as png
plt.show()
print("final tap root length: ", v1_[-1], "cm")
# Out:
# final tap root length:  85.85288555139974 cm

# %% [markdown]
# ## 2.2 Analyse results from the class *SegmentAnalyser* (values per segment) in a loop
#
# The main functionality of the *SegmentAnalyser* class is:
# * *getParameter(name)* as for *RootSystem* class, but returning a value for each segment, especially the "creationTime" of each segment
# * *filter(name, min, max)* will keep only segments where the value of parameter *name* is within [min, max]
# * *crop(sdf)* will keep only segments inside a geometry (e.g. in a soil core), segments intersecting the domain boundary are cut.
# * *distribution(...)* will create a 1d plot versus depth, where parameters are summed in layers
# * *distribution2d(...)* as above but 2d
# * *mapPeriodic(length, width)* maps the unconstrained root system into a periodic domain
# * *addData(name, data)* attach user data to the segments (e.g. simulation results for visualization or export)
#
# Note that *SegmentAnalyser* is only loosly connected to the original simulation.
#
# The first example shows how to obtain a depth distribution (values per segment) in a simulation loop.

# %%
s = pb.RootSystem()
path = "../../../modelparameter/structural/rootsystem/"
name = "Lupinus_albus_Leitner_2014"
rs.readParameters(path + name + ".xml")
rs.setGeometry(pb.SDF_PlantBox(1.e6,1.e6,1.e6)) 
rs.initialize()

simtimes = [0,10,20,40,60] # day
dt_ = np.diff(simtimes) # day
depth = 50 # cm
layers = 60 # [1]

""" Simulation loop """
rsd_ = []
for dt in dt_:    
    rs.simulate(dt)
    # _ = vp.plot_roots(rs, "subType") # to observe growth
    ana = pb.SegmentAnalyser(rs) # create a SegmentAnalyser object
    rsd = ana.distribution("surface", 0., -depth, layers, True)
    rsd_.append(rsd) # store relevant data in a list

""" vizualize rld_ """
soilvolume = (depth / layers) * 10 * 10
rsd_ = np.array(rsd_) / soilvolume  # convert to density [cm2/cm3]

z_ = np.linspace(0, -depth, layers)  # z - axis
for i, t in enumerate(simtimes[1:]):
    plt.plot(rsd_[i,:], z_, label = "at time "+str(t))

plt.xlabel("root surface (cm^2 / cm^3)")
plt.ylabel("z-coordinate (cm)")
plt.legend()
# plt.savefig("surface_density.png")
plt.show()
_ = vp.plot_roots(rs, "subType",interactiveImage = not isColab) # final result

# %% [markdown]
# ## 3. Simulate a full plant

# %% [markdown]
# The definition of full plants is similar to that of root systems. Only, there are new parameters to take into account.

# %%
#create a plant from a parameter file
plant = pb.Plant()
path = "../../../modelparameter/structural/plant/"
name = "fspm2023"
plant.readParameters(path + name + ".xml")

# %%
# choose which organ parameters to overwrite
adaptSeed = False #change seed parameter
adaptRoot = False #change seed parameter
adaptLeaf = False #change leaf parameter
leafRadial = False #radial or not
adaptStem = False #change stem parameters
radialLeafShapeOptions = ["long","maple", "round", "flower"]
radialLeafShape = radialLeafShapeOptions[3]

# %% [markdown]
# Within the seed parameters are defined the number of tillers and basal roots. Roots and stems are (among others) defined according to their maximal lengths, growth rate and the distance between two children organs (roots, stems or leaves growing out of the organ in question).

# %%
if adaptSeed:
    srp = pb.SeedRandomParameter(plant)  # with default values
    srp.firstTil = 0  # [day] first emergence of a tiller
    srp.delayTil = 0  # [day] delay between the emergence of tillers
    srp.maxTil = 20 # [-] number of tillers 
    srp.firstB = 0  # [day] first emergence of a tiller
    srp.delayB = 0  # [day] delay between the emergence of tillers
    srp.maxB = 20 # [-] number of tillers 
    plant.setOrganRandomParameter(srp)
if adaptRoot:
    for p in plant.getOrganRandomParameter(pb.root):#we go through the root subtypes
        p.dxMin = 0.01 #resolution == minimum segment length
        p.dx = 0.1 #resolution == maximum segment length
        if p.subType == 1: #to which root subtype are the changes applied? Here: tap roots
            p.r = 10  # [cm/day] growth rate
            p.lmax = 20  # [cm] maximum length
            p.ln = 1 # [cm] interlateral distance
        plant.setOrganRandomParameter(p)
if adaptStem:
    for p in plant.getOrganRandomParameter(pb.stem):
        p.dxMin = 0.01 #resolution == minimum segment length
        p.dx = 0.1 #resolution == maximum segment length
        p.r = 10  # [cm/day] growth rate
        p.lmax = 20  # [cm] maximum length
        p.ln = 1 # [cm] interlateral distance
        plant.setOrganRandomParameter(p)

# %% [markdown]
# The leaf parameters can be adapted to represent different leaf 2D shapes. The 2D shapes can be defined according to the distance from the leaf center vain (non-radial geometry) or according to the distance from the leaf center (radial geometry).

# %%
if adaptLeaf:
    for p in plant.getOrganRandomParameter(pb.leaf):
        if leafRadial:
            if radialLeafShape=="long":
                p.lb =  1 # length of leaf stem
                p.la,  p.lmax = 3.5, 8.5
                p.areaMax = 10  # cm2, area reached when length = lmax
                N = 100  # resolution of the leaf shape
                phi = np.array([-90, -45, 0., 45, 90]) / 180. * np.pi
                l = np.array([3, 2.2, 1.7, 2, 3.5]) #distance from leaf center

            elif radialLeafShape == "maple":
                p.lb =  1 # length of leaf stem
                N = 100  # resolution of the leaf shape
                p.areaMax = 50 
                p.la,  p.lmax = 5, 11
                phi = np.array([-90, -45, 0., 45,67.5,70, 90]) / 180. * np.pi
                l = np.array([2, 2, 2, 4,1,1, 4]) #distance from leaf center

            elif radialLeafShape == "round":
                p.lb =  1 # length of leaf stem
                N = 100  # resolution of the leaf shape
                p.la,  p.lmax = 5, 11
                p.areaMax = 3.145*(((p.lmax-p.la - p.lb)/2)**2)
                phi = np.array([-90, -45, 0., 45,67.5,70, 90]) / 180. * np.pi
                l_ = (p.lmax - p.lb - p.la)/2
                l = np.array([l_ for x_i in range(len(phi))]) 

            elif radialLeafShape == "flower":
                N = 100  # resolution of the leaf shape
                p.areaMax = 100 
                p.la, p.lb, p.lmax = 5, 1, 11
                phi = np.array([-90., -67.5, -45, -22.5, 0, 22.5, 45, 67.5, 90]) / 180. * np.pi
                l = np.array([5., 1, 5, 1, 5, 1, 5, 1, 5])

            p.createLeafRadialGeometry(phi, l, N)   

        else:
            p.parametrisationType=1
            p.lb =  2 # length of leaf sheath
            p.la,  p.lmax = 3.5, 8.5
            p.areaMax = 10  # cm2, area reached when length = lmax
            N = 100  
            y = np.array([-3, -2.1, 0., 2.45, 3.5])
            l = np.array([0., 1.54, 1.7, 1.26, 0.])
            p.createLeafGeometry(y, l, N)         


        p.tropismT = 1 # 1: gravitropism
        #p.tropismN = 5
        #p.tropismS = 0.1
        plant.setOrganRandomParameter(p)

# %%
plant.initialize()

# %% [markdown]
# CPlantBox offers the option to print several vtk files to create a video of the growth in Paraview. When running the simulation on Colab, it is possible to print images at regular intervals.

# %%
seeGrowth = True #see plant development at each time step
    
# Simulate
dt = 1 #time step [day]
N = 30 # number of steps [-]
for i in range(N):
    plant.simulate(dt, True)
    if seeGrowth:
        vp.plot_plant(plant, "organType",interactiveImage = not isColab)
# Plot, using vtk
vp.plot_plant(plant, "organType",interactiveImage = not isColab)

# zoom on one leaf--theoreticall 2D shape once fully grown
print("2D leaf shape of a full grown leaf")
lorg = plant.getOrgans(pb.leaf)[0]
lrp = lorg.getLeafRandomParameter()  
if leafRadial:
    yy = np.linspace(0, lorg.leafLength(), N)
    geom_x, geom_y = [],[]
    for i, x in enumerate(lrp.leafGeometry):
        geom_x.extend(x)
        geom_y.extend([yy[i]] * len(x))
    geom_x = np.array(geom_x)
    geom_y = np.array(geom_y)        
    a  = lorg.leafArea() / lorg.leafLength() # scale radius
    plt.plot(geom_x * a, geom_y, "g*")
    plt.plot(-geom_x * a, geom_y, "g*")

else:
    geom_x_a =  np.array([0])
    geom_x_b = np.array([ x[-1] for x in lrp.leafGeometry]) #normalized x value along length
    geom_x = np.concatenate((geom_x_a,geom_x_b))
    geom_y_a = np.array([0])
    geom_y_b =np.linspace(lrp.lb, lorg.leafLength()+lrp.lb, len(geom_x_b))
    geom_y = np.concatenate((geom_y_a,geom_y_b))
    a  = lorg.leafArea() / lorg.leafLength() # scale radius
    plt.plot(geom_x * a, geom_y, "g-*")
    plt.plot(-geom_x * a, geom_y, "g-*")
plt.ylim([0, lrp.lmax+1])
plt.xlim([-a-1, a+1])
plt.axis('scaled')
plt.show()
# Out:
# Tiller stem type #4 was not defined, using main stem parameters instead, Organism::simulate: from 0 to 1 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.352634 < 1) and kept in memory
# Organism::simulate: from 1 to 2 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.613019 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.352634 < 1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (5.55112e-17 < 0.1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.898335 < 1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.898335 < 1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.898335 < 1) and kept in memory
# Organism::simulate: from 2 to 3 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.784774 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.613019 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organism::simulate: from 3 to 4 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.871373 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.784774 < 1) and kept in memory
# Organism::simulate: from 4 to 5 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.876155 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.871373 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.352634 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organism::simulate: from 5 to 6 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802328 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.876155 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.613019 < 1) and kept in memory
# Organism::simulate: from 6 to 7 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.652976 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802328 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.784774 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.0170735 < 0.1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.0170735 < 0.1) and kept in memory
# Organism::simulate: from 7 to 8 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.35312 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.35312 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.431058 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.652976 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.871373 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.352634 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.898335 < 1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.898335 < 1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.898335 < 1) and kept in memory
# Organism::simulate: from 8 to 9 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.592731 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.592731 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.185375 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.185375 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.745952 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.745952 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.271142 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.271142 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.757196 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.757196 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.199867 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.199867 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.13942 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.35312 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.35312 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.431058 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.876155 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.613019 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.431819 < 0.5) and kept in memory
# Organism::simulate: from 9 to 10 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.297626 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.297626 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.929035 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.929035 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.531428 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.531428 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.101803 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.101803 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.636765 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.636765 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.132473 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.132473 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.58456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.58456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.780797 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.592731 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.592731 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.185375 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.185375 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.745952 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.745952 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.271142 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.271142 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.757196 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.757196 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.199867 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.199867 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.13942 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802328 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.784774 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) a
# nd kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.15499 < 0.5) and kept in memory
# Organism::simulate: from 10 to 11 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.935441 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.935441 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.601926 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.601926 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.242157 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.242157 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.853416 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.853416 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.432632 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.432632 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97633 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97633 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.480558 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.480558 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.940816 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.940816 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351961 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351961 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.357815 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.297626 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.297626 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.929035 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.929035 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.531428 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.531428 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.101803 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.101803 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.636765 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.636765 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.132473 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.132473 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.58456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.58456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.780797 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.652976 < 1) and kept in m
# emory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.871373 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.352634 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.460334 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.327308 < 0.5) and kept in memory
# Organism::simulate: from 11 to 12 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.51256 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.51256 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.210783 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.210783 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.885251 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.885251 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.533503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.533503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.152763 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.152763 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.739883 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.739883 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.29129 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.29129 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802912 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802912 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.270094 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.270094 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.687499 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.687499 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0489846 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0489846 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.872996 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.935441 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.935441 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.601926 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.601926 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.242157 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.242157 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.853416 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.853416 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.432632 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.432632 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97633 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97633 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.480558 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.480558 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.940816 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.940816 < 1) and kept in m
# emory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351961 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351961 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.357815 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.35312 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.35312 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.431058 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.876155 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.613019 < 1) and kept in memory
# Organism::simulate: from 12 to 13 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0347593 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0347593 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.7617 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.7617 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.467146 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.467146 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.148872 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.148872 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.804363 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.804363 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.430774 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.430774 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0248708 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0248708 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.582968 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.582968 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.100854 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.100854 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.5737 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.5737 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.995949 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.995949 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.36118 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.36118 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.328767 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.51256 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.51256 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.210783 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.210783 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.885251 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.885251 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.533503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.533503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.152763 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.152763 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.739883 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.739883 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.29129 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.29129 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802912 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802912 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.270094 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.270094 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.687499 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.687499 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0489846 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0489846 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.872996 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.592731 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.592731 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.185375 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.185375 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.745952 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.745952 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.271142 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.271142 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.757196 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.757196 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.199867 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.199867 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.13942 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.00123318 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.802328 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.784774 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.0196876 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dx
# Min threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.123407 < 0.5) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.0170735 < 0.1) and kept in memory
# Organ::createSegments(): 3 length increment below dxMin threshold (0.0170735 < 0.1) and kept in memory
# Organism::simulate: from 13 to 14 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.507264 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.507264 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.26019 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.26019 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.993667 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.993667 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.70568 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.70568 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.393956 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.393956 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0559189 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0559189 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.688642 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.688642 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.288792 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.288792 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852557 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852557 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.375569 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.375569 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852798 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852798 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.278435 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.278435 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.645745 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.645745 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.727456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0347593 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0347593 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.7617 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.7617 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.467146 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.467146 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.148872 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.148872 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.804363 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.804363 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.430774 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.430774 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0248708 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0248708 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.582968 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.582968 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.100854 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.100854 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.5737 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.5737 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.995949 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.995949 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.36118 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.36118 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.328767 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.297626 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.297626 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.929035 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.929035 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.531428 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.531428 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.101803 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.101803 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.636765 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.636765 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.132473 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.132473 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.58456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.58456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.780797 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.952742 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.455195 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.652976 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.871373 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.352634 < 1) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5)
#  and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.275634 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organ::createSegments(): 4 length increment below dxMin threshold (0.487682 < 0.5) and kept in memory
# Organism::simulate: from 14 to 15 days
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0866727 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0866727 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.934805 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0866727 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0866727 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.934805 < 1) and kept in memory
# ...
# Organ::createSegments(): 2 length increment below dxMin threshold (0.932026 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.379694 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.379694 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.75433 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.75433 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0430324 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0430324 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.230003 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.230003 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.29574 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.29574 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0888575 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.962185 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.962185 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.962185 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.962185 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.702388 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.702388 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.702388 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.702388 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.413794 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.413794 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.413794 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.413794 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.092449 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.092449 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.092449 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.092449 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.92218 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.92218 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.92218 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.92218 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.625106 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.625106 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.625106 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.625106 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.290759 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.290759 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.290759 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.290759 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.815623 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.815623 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.528721 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.528721 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.213504 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.213504 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.866276 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.866276 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.482734 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.482734 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0578453 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0578453 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.585697 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.585697 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0593095 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0593095 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.470402 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.470402 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.809092 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.809092 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.063522 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.063522 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.219368 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.219368 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0402622 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.85853 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.85853 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.85853 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.85853 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.589868 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.589868 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.589868 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.589868 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.291427 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.291427 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.291427 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.291427 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.846941 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.846941 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.596516 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.596516 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.324431 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.324431 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0282146 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0282146 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.705044 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.705044 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351683 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351683 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.964404 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.964404 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.538906 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.538906 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0701976 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0701976 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.55247 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.55247 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97893 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97893 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.341596 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.341596 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.631048 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.631048 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.60298 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.507264 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.507264 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.26019 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.26019 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.993667 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.993667 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.70568 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.70568 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.393956 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.393956 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0559189 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.0559189 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.688642 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.688642 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.288792 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (2.22045e-16 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.288792 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852557 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852557 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.375569 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.375569 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852798 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.852798 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.278435 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.278435 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.645745 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.645745 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.727456 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.935441 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.935441 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.601926 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.601926 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.242157 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.242157 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.853416 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.853416 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.432632 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.432632 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97633 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.97633 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.480558 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.480558 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.940816 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.940816 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351961 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.351961 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.357815 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.813702 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.363503 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.877866 < 1) and kept in memory
# Organ::createSegments(): 2 length increment below dxMin threshold (0.35312 < 1) and kept in memory
# Organ::createSegments(
# 2D leaf shape of a full grown leaf

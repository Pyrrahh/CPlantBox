# %% [markdown]
# # Summer School - Modeling Water Fluxes In The Soil-Plant System
#
# ## Coupled soil root hydraulics

# %%
import timeit
from functools import partial

import matplotlib.pyplot as plt
import numpy as np

import functional.van_genuchten as vg
import plantbox as pb
import visualisation.vtk_plot as vp
from functional.Perirhizal import PerirhizalPython as Perirhizal
from functional.PlantHydraulicModel import HydraulicModel_Doussan, HydraulicModel_Meunier
from functional.PlantHydraulicParameters import PlantHydraulicParameters
from richards import RichardsWrapper  # Python part
from rosi_richards import RichardsSP  # C++ part (Dumux binding)

sourcedir = "/home/jhack/phd/CPlantBox/"

# %%
def make_source(q: np.ndarray, area: float) -> dict[int, float]:
    """
    Create a source term dictionary for the soil model from given fluxes and area.
    
    Args:
        q (np.ndarray): Array of fluxes [cm/day].
        area (float): Area of each soil cell [cm²].
    
    Returns:
        dict[int, float]: Dictionary mapping cell indices to source terms [cm³/day].
    """
    s = {}
    for i in range(len(q)):
        if not np.isnan(q[i]):
            s[i] = -q[i] * area  # Negative because flux into root is a sink in soil

    return s

def soil_picker(x: float, y: float, z: float, soil_model) -> int:
    """
    Maps a 3D coordinate (x, y, z) to the corresponding soil grid cell index.

    This function wraps the Richards solver's `pick()` method, which returns
    the index of the grid cell containing the given coordinates. It is used
    to couple plant root segments to the soil model in CPlantBox simulations.

    Args:
        x (float): X-coordinate [cm].
        y (float): Y-coordinate [cm].
        z (float): Z-coordinate [cm].
        soil_model: The soil model object (e.g. a RichardsWrapper instance).

    Returns:
        int: The index of the soil grid cell containing the point (x, y, z).
    """
    return soil_model.pick([x, y, z])

def sinusoidal(t: float) -> float:
    """ 
    Sinusoidal function (used for transpiration) (integral over one day is 1).
    
    Args:
        t (float): Time [days].
    
    Returns:
        float: Sinusoidal value at time t.
    """
    return np.sin(2. * np.pi * np.array(t) - 0.5 * np.pi) + 1.

# %% [markdown]
# ## The alpha and omega of RWU (Vanderborght et al. 2024)

# %%
""" Parameters """  
verbose = False # toggle detailed logging
depth = -100
N = 100
min_b = [-10., -10., depth]  # [cm]
max_b = [10., 10., 0.]  # [cm]
cell_number = [1, 1, N]  # [cm3]
periodic = True

kx = 10 * 4.32e-2  # axial conductivity [cm3/day]
kr = 1.728e-4  # radial conductivity [1/day]

path = sourcedir + "modelparameter/structural/rootsystem/"
name = "Zeamays_synMRI_modified"  #"Anagallis_femina_Leitner_2010"  # Zea_mays_1_Leitner_2010, Zeamays_synMRI.xml  <<<<-------
trans = 1.5 * 400  # cm3 /day (sinusoidal) = mL/day; potential transpiration rate
wilting_point = -15000  # cm
rs_age = 60  # root system initial age [day]

loam = [0.01, 0.43, 0.0083, 1.2539, 2.272]  # jan paper
sp = vg.Parameters(loam)  # needed for Perirhizal class
vg.create_mfp_lookup(sp, wilting_point = -16000, n = 1501)  # needed for Perirhizal class; precomputes a lookup table for matric potential in rhizosphere cylinder
initial = -500  # cm (-330 )

sim_time = 7  # [day]
dt = 3600. / (24 * 3600)  # [days]
# Out:
# initializing look up tables
# done

# %%
""" Initialize macroscopic soil model """
s = RichardsWrapper(RichardsSP()) # create macroscopic 3D soil model using Richards equation
s.initialize()
s.createGrid(min_b, max_b, cell_number, periodic)  # [cm]
s.setHomogeneousIC(initial, False)  # [cm] False = matrix, True, = total potential; inital matric potential in each cell
s.setTopBC("noFlux")
s.setBotBC("noFlux")
s.setVGParameters([loam])
s.setParameter("Soil.SourceSlope", "100") 
s.initializeProblem()
s.setCriticalPressure(wilting_point)  

""" Initialize xylem model """
plant = pb.MappedPlant() 
plant.enableExtraNode()
plant.readParameters(path + name + ".xml")
sdf = pb.SDF_PlantBox(np.inf, np.inf, max_b[2] - min_b[2] - 0.5)  
plant.setGeometry(sdf)  
plant.setRectangularGrid(pb.Vector3d(min_b), pb.Vector3d(max_b), pb.Vector3d(cell_number), False, False)  # needed for Perirhizal class --> grid for coupling

""" root hydraulic properties """
params = PlantHydraulicParameters() # object to store root xylem & radial conductivities
params.read_parameters(sourcedir + "modelparameter/functional/plant_hydraulics/couvreur2012")
# params.set_kr_const(kr) # set radial conductivity manually
# params.set_kx_const(kx)
# params.plot_conductivities(True) # plot conductivities
hm = HydraulicModel_Doussan(plant, params)
hm.wilting_point = wilting_point  

""" Coupling (map indices) """
picker = partial(soil_picker, soil_model=s) # map each root segment to soil grid cell
plant.setSoilGrid(picker)
plant.initialize(True)
plant.simulate(rs_age, True) # grow root system to initial age (in days)
hm.test() 

peri = Perirhizal(plant) # set local cylindrical soil domains around each root segment
h_bs = s.getSolutionHead() # current matric potential in soil
h_sr = np.ones(h_bs.shape) * wilting_point # initial guess for matric potential at root-soil interface as wilting point
# Out:
# Computed bounding box tree with 199 nodes for 100 grid entities in 0.0003047 seconds.
# Computed bounding box tree with 199 nodes for 100 grid entities in 3.95e-05 seconds.
# MappedPlant::initializeLB
# Seed::initialize: RootSystem
# Seed::initialize: Shoot borne definition is DEPRICATED, shoot borne roots will be handeled like basal roots
# Organism::simulate: from 0 to 60 days
# nodes moved 0
# new nodes added 54110
# segments added 54110
# Number of segments 54111, including 54110 new
# PlantHydraulicModel.test():
# 54112 nodes:
# Node 0 [ 0.1  0.  -3. ]
# Node 1 [ 0.  0. -3.]
# Node 2 [ 0.05710218  0.02889541 -3.49588748]
# Node 3 [ 0.12191282  0.06395217 -3.99042828]
# Node 4 [ 0.19557912  0.04947684 -4.35951016]
# 54111 segments:
# Segment 0 [0 1] subType 0
# Segment 1 [1 2] subType 1
# Segment 2 [2 3] subType 1
# Segment 3 [3 4] subType 1
# Segment 4 [4 5] subType 2
# Collar segment index 0
# Collar segment [0 1]
# 0 segments with length < 1.e-5 cm
# 6 different root types from 0 to 5
# ages from 0 to 60
# segments 54111 54111
# Warning: root segment  364 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.83675332   9.84931639 -23.53756757] [ -0.70540314  10.3310312  -23.51114848]
# Warning: root segment  365 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.70540314  10.3310312  -23.51114848] [ -0.55484559  10.80748812 -23.52907136]
# Warning: root segment  366 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.55484559  10.80748812 -23.52907136] [ -0.37815367  11.16596239 -23.54568954]
# Warning: root segment  369 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.37815367  11.16596239 -23.54568954] [ -0.27651113  11.64605387 -23.44987222]
# Warning: root segment  370 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.27651113  11.64605387 -23.44987222] [ -0.27392122  11.79847774 -23.44612206]
# Warning: root segment  374 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.48923163  10.03974538 -24.10825975] [-1.29787564e-02  1.00209070e+01 -2.42593502e+01]
# Warning: root segment  391 is not mapped (out of the soil domain), this could cause problems with coupling! [ -1.16942779  10.02166421 -25.19950178] [ -0.73254051  10.20457742 -25.35972744]
# Warning: root segment  392 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.73254051  10.20457742 -25.35972744] [ -0.52248887  10.52623108 -25.67975436]
# Warning: root segment  393 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.52248887  10.52623108 -25.67975436] [ -0.38630402  10.82153323 -25.91267136]
# Warning: root segment  396 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.38630402  10.82153323 -25.91267136] [ -0.05520193  11.10668375 -26.15569519]
# Warning: root segment  397 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.05520193  11.10668375 -26.15569519] [  0.04338995  11.19776599 -26.22806559]
# Warning: root segment  400 is not mapped (out of the soil domain), this could cause problems with coupling! [ -1.39674067  10.08425738 -25.71753604] [ -1.06397367  10.36492608 -25.96348565]
# Warning: root segment  401 is not mapped (out of the soil domain), this could cause problems with coupling! [ -1.06397367  10.36492608 -25.96348565] [ -1.13274772  10.64118034 -26.37452544]
# Warning: root segment  402 is not mapped (out of the soil domain), this could cause problems with coupling! [ -1.13274772  10.64118034 -26.37452544] [ -0.90441915  10.95107002 -26.48331172]
# Warning: root segment  405 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.90441915  10.95107002 -26.48331172] [ -0.50496837  11.23996862 -26.39978524]
# Warning: root segment  406 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.50496837  11.23996862 -26.39978524] [ -0.38471601  11.3318661  -26.41844079]
# Warning: root segment  427 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.17875792  10.25100326 -27.16340827] [ -1.73731553  10.43061593 -27.31462962]
# Warning: root segment  428 is not mapped (out of the soil domain), this could cause problems with coupling! [ -1.73731553  10.43061593 -27.31462962] [ -1.29346459  10.6068478  -27.46274672]
# Warning: root segment  429 is not mapped (out of the soil domain), this could cause problems with coupling! [ -1.29346459  10.6068478  -27.46274672] [ -0.94696307  10.7506308  -27.60153845]
# Warning: root segment  432 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.94696307  10.7506308  -27.60153845] [ -0.54754039  11.03914311 -27.68652181]
# Warning: root segment  433 is not mapped (out of the soil domain), this could cause problems with coupling! [ -0.54754039  11.03914311 -27.68652181] [ -0.42631802  11.128721   -27.70964641]
# Warning: root segment  436 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.49131816  10.47200465 -27.5845126 ] [ -2.92886913  10.38909547 -27.35719075]
# Warning: root segment  437 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.92886913  10.38909547 -27.35719075] [ -3.27322084  10.23426771 -27.02939469]
# Warning: root segment  438 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.27322084  10.23426771 -27.02939469] [ -3.66384607  10.19326292 -26.95369439]
# Warning: root segment  441 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.66384607  10.19326292 -26.95369439] [ -4.01999541   9.9701964  -26.68277193]
# Warning: root segment  445 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.8273366   10.67294878 -27.99688635] [ -3.16485707  10.9223804  -27.7251074 ]
# Warning: root segment  446 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.16485707  10.9223804  -27.7251074 ] [ -3.53617504  11.10323866 -27.44330383]
# Warning: root segment  447 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.53617504  11.10323866 -27.44330383] [ -3.80375598  11.20709107 -27.16470892]
# Warning: root segment  450 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.80375598  11.20709107 -27.16470892] [ -4.24034325  11.27693252 -26.93122718]
# Warning: root segment  451 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.24034325  11.27693252 -26.93122718] [ -4.36241252  11.33684011 -26.86220558]
# Warning: root segment  454 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.13921105  10.86393963 -28.43256373] [ -2.75178859  11.11787101 -28.6207729 ]
# Warning: root segment  455 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.75178859  11.11787101 -28.6207729 ] [ -2.34978624  11.37679797 -28.76689251]
# Warning: root segment  456 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.34978624  11.37679797 -28.76689251] [ -2.05230202  11.55459338 -28.96662215]
# Warning: root segment  459 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.05230202  11.55459338 -28.96662215] [ -2.00076079  11.84242411 -29.37220442]
# Warning: root segment  460 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.00076079  11.84242411 -29.37220442] [ -1.97251845  11.93081606 -29.49321285]
# Warning: root segment  463 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.37307413  11.00963646 -28.93050815] [ -2.96510877  10.92279098 -29.20622925]
# Warning: root segment  464 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.96510877  10.92279098 -29.20622925] [ -2.50727617  10.97517019 -29.40025433]
# Warning: root segment  465 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.50727617  10.97517019 -29.40025433] [ -2.22145291  10.88074777 -29.66367315]
# Warning: root segment  468 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.22145291  10.88074777 -29.66367315] [ -1.81886254  10.81552095 -29.9529247 ]
# Warning: root segment  469 is not mapped (out of the soil domain), this could cause problems with coupling! [ -1.81886254  10.81552095 -29.9529247 ] [ -1.70443365  10.76887823 -30.04227956]
# Warning: root segment  472 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.64314694  11.15677381 -29.40855034] [ -3.32686016  11.53983449 -29.46535873]
# Warning: root segment  473 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.32686016  11.53983449 -29.46535873] [ -3.01846087  11.92844843 -29.52756065]
# Warning: root segment  474 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.01846087  11.92844843 -29.52756065] [ -2.81292467  12.23937445 -29.67274977]
# Warning: root segment  477 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.81292467  12.23937445 -29.67274977] [ -2.69731952  12.67791527 -29.88326675]
# Warning: root segment  478 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.69731952  12.67791527 -29.88326675] [ -2.65093246  12.80490243 -29.95380972]
# Warning: root segment  481 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.94682548  11.19621632 -29.88792414] [ -3.97596879  11.68521195 -29.78775455]
# Warning: root segment  482 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.97596879  11.68521195 -29.78775455] [ -4.09340678  12.16953112 -29.74721742]
# Warning: root segment  483 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.09340678  12.16953112 -29.74721742] [ -4.18856534  12.55722525 -29.72195662]
# Warning: root segment  486 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.18856534  12.55722525 -29.72195662] [ -4.30235783  13.04038801 -29.66191479]
# Warning: root segment  487 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.30235783  13.04038801 -29.66191479] [ -4.33330675  13.17248902 -29.59230665]
# Warning: root segment  490 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.31375797  11.22426333 -30.32156665] [ -4.06732605  11.25715818 -30.75537449]
# Warning: root segment  491 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.06732605  11.25715818 -30.75537449] [ -3.8792019   11.59488573 -31.07246975]
# Warning: root segment  492 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.8792019   11.59488573 -31.07246975] [ -3.54700696  11.78393195 -31.19040214]
# Warning: root segment  495 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.54700696  11.78393195 -31.19040214] [ -3.19412023  12.13594185 -31.22989877]
# Warning: root segment  496 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.19412023  12.13594185 -31.22989877] [ -3.09065364  12.2347966  -31.28258852]
# Warning: root segment  499 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.66241828  11.24282642 -30.77054771] [ -4.95069994  10.83588804 -30.73456378]
# Warning: root segment  500 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.95069994  10.83588804 -30.73456378] [ -5.24822439  10.43599548 -30.6950019 ]
# Warning: root segment  501 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.24822439  10.43599548 -30.6950019 ] [ -5.49033542  10.11775339 -30.68479316]
# Warning: root segment  508 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.99021152  11.24432959 -31.23525655] [ -5.43305134  11.30842677 -31.01213228]
# Warning: root segment  509 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.43305134  11.30842677 -31.01213228] [ -5.88687412  11.37366078 -30.81265946]
# Warning: root segment  510 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.88687412  11.37366078 -30.81265946] [ -6.25075678  11.43225586 -30.65723737]
# Warning: root segment  513 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.25075678  11.43225586 -30.65723737] [ -6.69769743  11.51622042 -30.44940567]
# Warning: root segment  514 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.69769743  11.51622042 -30.44940567] [ -6.81805037  11.55999806 -30.36662588]
# Warning: root segment  517 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.28054994  11.30449729 -31.72112241] [ -5.66638078  11.51475721 -31.48253212]
# Warning: root segment  518 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.66638078  11.51475721 -31.48253212] [ -6.01682105  11.71703722 -31.18880705]
# Warning: root segment  519 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.01682105  11.71703722 -31.18880705] [ -6.29795621  11.85621114 -30.94062639]
# Warning: root segment  522 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.29795621  11.85621114 -30.94062639] [ -6.75234468  12.02287348 -30.81510833]
# Warning: root segment  523 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.75234468  12.02287348 -30.81510833] [ -6.89709334  12.06443375 -30.79114221]
# Warning: root segment  526 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.65915074  11.36336777 -32.14182613] [ -5.43515615  11.72668565 -32.40226143]
# Warning: root segment  527 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.43515615  11.72668565 -32.40226143] [ -5.2594593   12.10358423 -32.67989081]
# Warning: root segment  528 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.2594593   12.10358423 -32.67989081] [ -5.11382667  12.47433047 -32.64330714]
# Warning: root segment  531 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.11382667  12.47433047 -32.64330714] [ -4.94855206  12.94086199 -32.71424828]
# Warning: root segment  532 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.94855206  12.94086199 -32.71424828] [ -4.88304646  13.07669617 -32.73687344]
# Warning: root segment  535 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.90092188  11.42250752 -32.6459502 ] [ -5.52249752  11.09672335 -32.6202659 ]
# Warning: root segment  536 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.52249752  11.09672335 -32.6202659 ] [ -5.2818841   10.72384134 -32.85062254]
# Warning: root segment  537 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.2818841   10.72384134 -32.85062254] [ -5.05247857  10.43284139 -33.00126163]
# Warning: root segment  540 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.05247857  10.43284139 -33.00126163] [ -4.71934107  10.09473647 -33.15843818]
# Warning: root segment  541 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.71934107  10.09473647 -33.15843818] [ -4.61868729  10.00202583 -33.22572384]
# Warning: root segment  544 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.92309819  11.1606513  -33.15035999] [ -5.76639692  11.54218221 -33.43298851]
# Warning: root segment  545 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.76639692  11.54218221 -33.43298851] [ -5.65532003  11.86420347 -33.79899975]
# Warning: root segment  546 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.65532003  11.86420347 -33.79899975] [ -5.58331064  12.1172286  -34.10031841]
# Warning: root segment  549 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.58331064  12.1172286  -34.10031841] [ -5.42260403  12.53487104 -34.32336139]
# Warning: root segment  550 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.42260403  12.53487104 -34.32336139] [ -5.37214134  12.65563941 -34.40160668]
# Warning: root segment  553 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.80456758  10.92754616 -33.65589256] [ -5.3728927   10.7128408  -33.52338445]
# Warning: root segment  554 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.3728927   10.7128408  -33.52338445] [ -4.89917398  10.61061275 -33.40033975]
# Warning: root segment  555 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.89917398  10.61061275 -33.40033975] [ -4.56443646  10.47363552 -33.2294947 ]
# Warning: root segment  558 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.56443646  10.47363552 -33.2294947 ] [ -4.19391556  10.30937447 -32.93669345]
# Warning: root segment  559 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.19391556  10.30937447 -32.93669345] [ -4.07530876  10.2244769  -32.89221159]
# Warning: root segment  562 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.68226147  10.70163521 -34.16363597] [ -6.02562348  11.04280908 -34.28894724]
# Warning: root segment  563 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.02562348  11.04280908 -34.28894724] [ -6.36844505  11.38404319 -34.41556739]
# Warning: root segment  564 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.36844505  11.38404319 -34.41556739] [ -6.65940414  11.58152671 -34.60620596]
# Warning: root segment  567 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.65940414  11.58152671 -34.60620596] [ -7.11609204  11.67685531 -34.78606317]
# Warning: root segment  568 is not mapped (out of the soil domain), this could cause problems with coupling! [ -7.11609204  11.67685531 -34.78606317] [ -7.25629764  11.71097686 -34.83537764]
# Warning: root segment  571 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.55533182  10.45465498 -34.66030426] [ -5.47653357  10.01363665 -34.43828248]
# Warning: root segment  580 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.37556435  10.17846751 -35.1238845 ] [ -4.92467036  10.39420529 -35.11156314]
# Warning: root segment  581 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.92467036  10.39420529 -35.11156314] [ -4.44113899  10.41453345 -34.98592803]
# Warning: root segment  582 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.44113899  10.41453345 -34.98592803] [ -4.16553164  10.69460031 -35.06078218]
# Warning: root segment  585 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.16553164  10.69460031 -35.06078218] [ -3.73695103  10.85513723 -34.85942044]
# Warning: root segment  586 is not mapped (out of the soil domain), this could cause problems with coupling! [ -3.73695103  10.85513723 -34.85942044] [ -3.6422901   10.94847448 -34.78471252]
# Warning: root segment  589 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.17240602   9.9298377  -35.5938849 ] [ -5.59303054  10.16123191 -35.73364087]
# Warning: root segment  590 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.59303054  10.16123191 -35.73364087] [ -6.00503251  10.3442848  -35.94984915]
# Warning: root segment  591 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.00503251  10.3442848  -35.94984915] [ -6.33570324  10.34609654 -36.17491265]
# Warning: root segment  594 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.33570324  10.34609654 -36.17491265] [ -6.77422547  10.5238093  -36.33651846]
# Warning: root segment  595 is not mapped (out of the soil domain), this could cause problems with coupling! [ -6.77422547  10.5238093  -36.33651846] [ -6.90379626  10.55221331 -36.41174098]
# Warning: root segment  599 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.83245801  10.04067386 -36.37436972] [ -4.68428142  10.39456676 -36.69499958]
# Warning: root segment  600 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.68428142  10.39456676 -36.69499958] [ -4.56511647  10.6773921  -36.95153329]
# Warning: root segment  603 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.56511647  10.6773921  -36.95153329] [ -4.42894599  11.05201531 -37.25338599]
# Warning: root segment  604 is not mapped (out of the soil domain), this could cause problems with coupling! [ -4.42894599  11.05201531 -37.25338599] [ -4.41632128  11.18630839 -37.32451821]
# Warning: root segment  613 is not mapped (out of the soil domain), this could cause problems with coupling! [ -5.76247476   9.99586479 -37.93333584] [ -5.78340064  10.0543893  -38.07258668]
# Warning: root segment  649 is not mapped (out of the soil domain), this could cause problems with coupling! [ -2.52626274  10.06002088 -38.91252324] [ -2.45299533  10.19361363 -38.90630456]
# Warning: root segment  945 is not mapped (out of the soil domain), this could cause problems with coupling! [  4.94631579   9.90652201 -53.55318654] [  4.55579708  10.20633972 -53.6403902 ]
# Warning: root segment  946 is not mapped (out of the soil domain), this could cause problems with coupling! [  4.55579708  10.20633972 -53.6403902 ] [  4.44840389  10.31349071 -53.62492492]
# Warning: root segment  950 is not mapped (out of the soil domain), this could cause problems with coupling! [  6.10121153   9.83169776 -53.67353087] [  5.79508361  10.22691342 -53.66402919]
# Warning: root segment  951 is not mapped (out of the soil domain), this could cause problems with coupling! [  5.79508361  10.22691342 -53.66402919] [  5.59593687  10.56654788 -53.59339628]
# Warning: root segment  954 is not mapped (out of the soil domain), this could cause problems with coupling! [  5.59593687  10.56654788 -53.59339628] [  5.33220055  10.98219307 -53.68104462]
# Warning: root segment  955 is not mapped (out of the soil domain), this could cause problems with coupling! [  5.33220055  10.98219307 -53.68104462] [  5.27685648  11.12420845 -53.685785  ]
# Warning: root segment  985 is not mapped (out of the soil domain), this could cause problems with coupling! [  7.72497109   9.88355872 -55.41602146] [  8.07396903  10.21746246 -55.28675922]
# Warning: root segment  986 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.07396903  10.21746246 -55.28675922] [  8.42258177  10.55173154 -55.15740179]
# Warning: root segment  987 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.42258177  10.55173154 -55.15740179] [  8.69043085  10.712505   -54.90758432]
# Warning: root segment  990 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.69043085  10.712505   -54.90758432] [  9.03147634  10.93705546 -54.61902746]
# Warning: root segment  991 is not mapped (out of the soil domain), this could cause problems with coupling! [  9.03147634  10.93705546 -54.61902746] [  9.13590454  11.00756927 -54.53314172]
# Warning: root segment  1003 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.484884     9.89577902 -56.25984632] [  8.39437529  10.30185179 -56.53717838]
# Warning: root segment  1004 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.39437529  10.30185179 -56.53717838] [  8.29103732  10.70314648 -56.81697088]
# Warning: root segment  1005 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.29103732  10.70314648 -56.81697088] [  8.19273849  10.97775036 -57.09070441]
# Warning: root segment  1008 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.19273849  10.97775036 -57.09070441] [  8.10310387  11.37294238 -57.38360184]
# Warning: root segment  1009 is not mapped (out of the soil domain), this could cause problems with coupling! [  8.10310387  11.37294238 -57.38360184] [  8.12111139  11.521642   -57.41220183]
# Warning: root segment  1026 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.09592865   8.87281666 -56.48842048] [ 10.02298504   8.43973151 -56.24942993]
# Warning: root segment  1027 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.02298504   8.43973151 -56.24942993] [ 10.0002028    8.30783246 -56.17637229]
# Warning: root segment  1048 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.4443794    9.70773846 -58.29841852] [ 10.78712978   9.90941479 -57.99535279]
# Warning: root segment  1049 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.78712978   9.90941479 -57.99535279] [ 11.27326381   9.95708079 -57.88857429]
# Warning: root segment  1050 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.27326381   9.95708079 -57.88857429] [ 11.56089795   9.87829643 -57.62200417]
# Warning: root segment  1053 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.56089795   9.87829643 -57.62200417] [ 11.88561194   9.86158248 -57.24216017]
# Warning: root segment  1054 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.88561194   9.86158248 -57.24216017] [ 11.98472853   9.85275261 -57.12661043]
# Warning: root segment  1057 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.91612369   9.6366173  -58.60874707] [ 10.61787721   9.23534468 -58.6141619 ]
# Warning: root segment  1058 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.61787721   9.23534468 -58.6141619 ] [ 10.57476297   8.77813871 -58.81190887]
# Warning: root segment  1059 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.57476297   8.77813871 -58.81190887] [ 10.52307513   8.40271047 -58.93990108]
# Warning: root segment  1062 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.52307513   8.40271047 -58.93990108] [ 10.41829825   7.94672173 -59.11624187]
# Warning: root segment  1063 is not mapped (out of the soil domain), this could cause problems with coupling! [ 10.41829825   7.94672173 -59.11624187] [ 10.3419738    7.85373102 -59.20994947]
# Warning: root segment  1066 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.31778377   9.5584004  -59.00214302] [ 11.4019312    9.06620681 -59.0279245 ]
# Warning: root segment  1067 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.4019312    9.06620681 -59.0279245 ] [ 11.43310031   8.56819866 -58.99604394]
# Warning: root segment  1068 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.43310031   8.56819866 -58.99604394] [ 11.4579815    8.17078411 -58.95806238]
# Warning: root segment  1071 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.4579815    8.17078411 -58.95806238] [ 11.4784673    7.67148646 -58.97486089]
# Warning: root segment  1072 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.4784673    7.67148646 -58.97486089] [ 11.46314789   7.56244819 -58.86936313]
# Warning: root segment  1075 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.74947497   9.5418446  -59.37276292] [ 11.52805987   9.8113461  -59.73101463]
# Warning: root segment  1076 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.52805987   9.8113461  -59.73101463] [ 11.35339274   9.99461942 -60.16217851]
# Warning: root segment  1077 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.35339274   9.99461942 -60.16217851] [ 11.26988292  10.05261839 -60.54904053]
# Warning: root segment  1080 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.26988292  10.05261839 -60.54904053] [ 11.02516166  10.15012614 -60.97401552]
# Warning: root segment  1081 is not mapped (out of the soil domain), this could cause problems with coupling! [ 11.02516166  10.15012614 -60.97401552] [ 10.93505501  10.18737895 -61.09126239]
# Warning: root segment  1084 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.22944425   9.55114136 -59.67795987] [ 12.40534829   9.80210825 -59.28289862]
# Warning: root segment  1085 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.40534829   9.80210825 -59.28289862] [ 12.5793088   10.06052476 -58.89179934]
# Warning: root segment  1086 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.5793088   10.06052476 -58.89179934] [ 12.81466775  10.194043   -58.59721651]
# Warning: root segment  1089 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.81466775  10.194043   -58.59721651] [ 13.17561877  10.41859328 -58.33398365]
# Warning: root segment  1090 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.17561877  10.41859328 -58.33398365] [ 13.23887159  10.49224321 -58.21638869]
# Warning: root segment  1093 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.75935994   9.55187146 -59.88552888] [ 12.83320358   9.99332171 -59.66266392]
# Warning: root segment  1094 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.83320358   9.99332171 -59.66266392] [ 12.86463559  10.42063677 -59.40495504]
# Warning: root segment  1095 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.86463559  10.42063677 -59.40495504] [ 12.90178109  10.79650658 -59.27326564]
# Warning: root segment  1098 is not mapped (out of the soil domain), this could cause problems with coupling! [ 12.90178109  10.79650658 -59.27326564] [ 13.09684102  11.22893186 -59.11527829]
# Warning: root segment  1099 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.09684102  11.22893186 -59.11527829] [ 13.14869971  11.37000188 -59.14104129]
# Warning: root segment  1102 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.28311194   9.50073142 -60.1024428 ] [ 13.48942622   9.78679626 -59.74804002]
# Warning: root segment  1103 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.48942622   9.78679626 -59.74804002] [ 13.68450212   9.96172121 -59.32219186]
# Warning: root segment  1104 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.68450212   9.96172121 -59.32219186] [ 13.77672959  10.21654893 -59.02798628]
# Warning: root segment  1107 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.77672959  10.21654893 -59.02798628] [ 13.97102379  10.54630859 -58.70625918]
# Warning: root segment  1108 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.97102379  10.54630859 -58.70625918] [ 14.02863763  10.64620542 -58.60648405]
# Warning: root segment  1111 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.8152232    9.38920778 -60.26742007] [ 13.68716888   9.14934614 -60.68702522]
# Warning: root segment  1112 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.68716888   9.14934614 -60.68702522] [ 13.77170054   8.94288909 -61.13449576]
# Warning: root segment  1113 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.77170054   8.94288909 -61.13449576] [ 13.69015486   8.89953392 -61.52368804]
# Warning: root segment  1116 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.69015486   8.89953392 -61.52368804] [ 13.70224057   8.64917275 -61.95632325]
# Warning: root segment  1117 is not mapped (out of the soil domain), this could cause problems with coupling! [ 13.70224057   8.64917275 -61.95632325] [ 13.69742696   8.58830199 -62.09605652]
# Warning: root segment  1120 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.35554311   9.23464656 -60.35774094] [ 14.3202873    8.91280392 -59.97672343]
# Warning: root segment  1121 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.3202873    8.91280392 -59.97672343] [ 14.30177072   8.60522766 -59.58295449]
# Warning: root segment  1122 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.30177072   8.60522766 -59.58295449] [ 14.27431366   8.36726882 -59.26260827]
# Warning: root segment  1125 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.27431366   8.36726882 -59.26260827] [ 14.22131157   7.94100861 -59.00669224]
# Warning: root segment  1126 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.22131157   7.94100861 -59.00669224] [ 14.21202      7.81481537 -58.92158795]
# Warning: root segment  1129 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.88839937   9.03806586 -60.32865599] [ 14.79157789   8.59950574 -60.10890471]
# Warning: root segment  1130 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.79157789   8.59950574 -60.10890471] [ 14.73491484   8.2883726  -59.72162514]
# Warning: root segment  1131 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.73491484   8.2883726  -59.72162514] [ 14.68744092   8.02240428 -59.42665551]
# Warning: root segment  1134 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.68744092   8.02240428 -59.42665551] [ 14.70447814   7.7299994  -59.02142827]
# Warning: root segment  1135 is not mapped (out of the soil domain), this could cause problems with coupling! [ 14.70447814   7.7299994  -59.02142827] [ 14.72041453   7.61360904 -58.9242011 ]
# Warning: root segment  1138 is not mapped (out of the soil domain), this could cause problems with coupling! [ 15.44174028   8.90492641 -60.31999362] [ 15.74293837   9.28916532 -60.21210397]
# Warning: root segment  1139 is not mapped (out of the soil domain), this could cause problems with coupling! [ 15.74293837   9.28916532 -60.21210397] [ 15.9805006    9.70055279 -60.05614073]
# Warning: root segment  1140 is not mapped (out of the soil domain), this could cause problems with coupling! [ 15.9805006    9.70055279 -60.05614073] [ 16.06330855  10.0482997  -59.87665555]
# Warning: root segment  1143 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.06330855  10.0482997  -59.87665555] [ 16.17237006  10.46496392 -59.6226939 ]
# Warning: root segment  1144 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.17237006  10.46496392 -59.6226939 ] [ 16.2116875   10.59509797 -59.55360647]
# Warning: root segment  1147 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.00864213   8.85965577 -60.31489653] [ 16.05020675   9.05174585 -60.77465057]
# Warning: root segment  1148 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.05020675   9.05174585 -60.77465057] [ 16.10758187   9.38453405 -61.14337827]
# Warning: root segment  1149 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.10758187   9.38453405 -61.14337827] [ 16.02114104   9.5832993  -61.47956327]
# Warning: root segment  1152 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.02114104   9.5832993  -61.47956327] [ 15.9289992    9.80236727 -61.91947134]
# Warning: root segment  1153 is not mapped (out of the soil domain), this could cause problems with coupling! [ 15.9289992    9.80236727 -61.91947134] [ 15.96145073   9.8785615  -62.04751486]
# Warning: root segment  1156 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.57296563   8.84674477 -60.35818151] [ 16.89852139   9.18760981 -60.19137482]
# Warning: root segment  1157 is not mapped (out of the soil domain), this could cause problems with coupling! [ 16.89852139   9.18760981 -60.19137482] [ 17.2214206    9.5285713  -60.01967344]
# Warning: root segment  1158 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.2214206    9.5285713  -60.01967344] [ 17.3700047    9.85763184 -59.84750514]
# Warning: root segment  1161 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.3700047    9.85763184 -59.84750514] [ 17.55099465  10.27435672 -59.63873968]
# Warning: root segment  1162 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.55099465  10.27435672 -59.63873968] [ 17.60634232  10.39405161 -59.56216569]
# Warning: root segment  1165 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.10654603   8.67370874 -60.45128727] [ 17.37146154   8.75232916 -60.03458762]
# Warning: root segment  1166 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.37146154   8.75232916 -60.03458762] [ 17.56825183   8.95396641 -59.62153072]
# Warning: root segment  1167 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.56825183   8.95396641 -59.62153072] [ 17.70199405   9.1101821  -59.27844228]
# Warning: root segment  1170 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.70199405   9.1101821  -59.27844228] [ 17.87493815   9.39235057 -58.90364728]
# Warning: root segment  1171 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.87493815   9.39235057 -58.90364728] [ 17.87667414   9.48851484 -58.78531205]
# Warning: root segment  1174 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.63047068   8.45459905 -60.48923189] [ 17.72492377   8.7641283  -60.10808854]
# Warning: root segment  1175 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.72492377   8.7641283  -60.10808854] [ 17.99021097   8.93397184 -59.71978984]
# Warning: root segment  1176 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.99021097   8.93397184 -59.71978984] [ 18.24703678   9.03684795 -59.43090058]
# Warning: root segment  1179 is not mapped (out of the soil domain), this could cause problems with coupling! [ 18.24703678   9.03684795 -59.43090058] [ 18.54518078   9.13242333 -59.04106022]
# Warning: root segment  1180 is not mapped (out of the soil domain), this could cause problems with coupling! [ 18.54518078   9.13242333 -59.04106022] [ 18.61587517   9.12639554 -58.90607957]
# Warning: root segment  1183 is not mapped (out of the soil domain), this could cause problems with coupling! [ 18.14759188   8.21854533 -60.51237114] [ 17.97424443   8.44027244 -60.09910639]
# Warning: root segment  1184 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.97424443   8.44027244 -60.09910639] [ 17.7943034    8.65267852 -59.68376932]
# Warning: root segment  1185 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.7943034    8.65267852 -59.68376932] [ 17.73327438   8.69135787 -59.29034923]
# Warning: root segment  1188 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.73327438   8.69135787 -59.29034923] [ 17.74237757   8.78966597 -58.80019349]
# Warning: root segment  1189 is not mapped (out of the soil domain), this could cause problems with coupling! [ 17.74237757   8.78966597 -58.80019349] [ 17.8173991    8.78485204 -58.66751944]
# Warning: root segment  1192 is not mapped (out of the soil domain), this could cause problems with coupling! [ 18.63951099   7.99269577 -60.33826507] [ 18.78495337   7.96187295 -60.8156501 ]
# Warning: root segment  1193 is not mapped (out of the soil domain), this could cause problems with coupling! [ 18.78495337   7.96187295 -60.8156501 ] [ 18.93160952   7.90290066 -61.29000677]
# Warning: root segment  1194 is not mapped (out of the soil domain), this could cause problems with coupling! [ 18.93160952   7.90290066 -61.29000677] [ 19.08570249   7.88960789 -61.65889517]
# Warning: root segment  1197 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.08570249   7.88960789 -61.65889517] [ 19.24539413   7.86682935 -62.13216013]
# Warning: root segment  1198 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.24539413   7.86682935 -62.13216013] [ 19.29887829   7.8728491  -62.27483814]
# Warning: root segment  1201 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.16505162   7.81504595 -60.21311819] [ 19.32137195   8.10950337 -60.5857558 ]
# Warning: root segment  1202 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.32137195   8.10950337 -60.5857558 ] [ 19.4427014    8.41381141 -60.96348028]
# Warning: root segment  1203 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.4427014    8.41381141 -60.96348028] [ 19.55892816   8.61858846 -61.28683411]
# Warning: root segment  1206 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.55892816   8.61858846 -61.28683411] [ 19.69872702   8.88404686 -61.68681925]
# Warning: root segment  1207 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.69872702   8.88404686 -61.68681925] [ 19.78200129   8.93876893 -61.80225191]
# Warning: root segment  1210 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.71808211   7.69087481 -60.16133317] [ 19.71359963   7.20321316 -60.27163284]
# Warning: root segment  1211 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.71359963   7.20321316 -60.27163284] [ 19.45723161   6.78110834 -60.34975427]
# Warning: root segment  1212 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.45723161   6.78110834 -60.34975427] [ 19.21051479   6.56599512 -60.57966101]
# Warning: root segment  1215 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.21051479   6.56599512 -60.57966101] [ 19.12136972   6.3031677  -60.99556353]
# Warning: root segment  1216 is not mapped (out of the soil domain), this could cause problems with coupling! [ 19.12136972   6.3031677  -60.99556353] [ 19.09414119   6.22316606 -61.12249718]
# Warning: root segment  1219 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.25945774   7.51772115 -60.15162946] [ 20.27988648   7.96047215 -60.38304728]
# Warning: root segment  1220 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.27988648   7.96047215 -60.38304728] [ 20.41763928   8.42788036 -60.49509072]
# Warning: root segment  1221 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.41763928   8.42788036 -60.49509072] [ 20.47406485   8.8178743  -60.56379939]
# Warning: root segment  1224 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.47406485   8.8178743  -60.56379939] [ 20.59962254   9.2983388  -60.62201565]
# Warning: root segment  1225 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.59962254   9.2983388  -60.62201565] [ 20.63846126   9.44255299 -60.65279922]
# Warning: root segment  1228 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.80768313   7.37287804 -60.10222253] [ 20.89779258   7.24456778 -59.62744178]
# Warning: root segment  1229 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.89779258   7.24456778 -59.62744178] [ 20.92706081   7.10278175 -59.14886045]
# Warning: root segment  1230 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.92706081   7.10278175 -59.14886045] [ 20.94472069   7.00808855 -58.760632  ]
# Warning: root segment  1233 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.94472069   7.00808855 -58.760632  ] [ 20.94188916   7.00040918 -58.26069899]
# Warning: root segment  1234 is not mapped (out of the soil domain), this could cause problems with coupling! [ 20.94188916   7.00040918 -58.26069899] [ 20.9388376    6.99473851 -58.10834303]
# Warning: root segment  1237 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.36683871   7.27428399 -60.14188894] [ 21.30919522   6.93142254 -60.50122618]
# Warning: root segment  1238 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.30919522   6.93142254 -60.50122618] [ 21.19963703   6.59113429 -60.85079865]
# Warning: root segment  1239 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.19963703   6.59113429 -60.85079865] [ 21.13457741   6.26808646 -61.07753053]
# Warning: root segment  1242 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.13457741   6.26808646 -61.07753053] [ 21.10327935   5.98255044 -61.48678548]
# Warning: root segment  1243 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.10327935   5.98255044 -61.48678548] [ 21.0716957    5.89643489 -61.60860662]
# Warning: root segment  1246 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.92813645   7.1900958  -60.18491779] [ 21.92291311   6.69104956 -60.15449464]
# Warning: root segment  1247 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.92291311   6.69104956 -60.15449464] [ 21.82011939   6.20196493 -60.1696498 ]
# Warning: root segment  1248 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.82011939   6.20196493 -60.1696498 ] [ 21.72748917   5.81295613 -60.17923067]
# Warning: root segment  1251 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.72748917   5.81295613 -60.17923067] [ 21.56455194   5.34024964 -60.17942117]
# Warning: root segment  1252 is not mapped (out of the soil domain), this could cause problems with coupling! [ 21.56455194   5.34024964 -60.17942117] [ 21.51642832   5.19555399 -60.18046674]
# Warning: root segment  1255 is not mapped (out of the soil domain), this could cause problems with coupling! [ 22.47294388   7.05977056 -60.28563741] [ 22.47920436   6.5809169  -60.42937319]
# Warning: root segment  1256 is not mapped (out of the soil domain), this could cause problems with coupling! [ 22.47920436   6.5809169  -60.42937319] [ 22.43928452   6.11641773 -60.6100578 ]
# Warning: root segment  1257 is not mapped (out of the soil domain), this could cause problems with coupling! [ 22.43928452   6.11641773 -60.6100578 ] [ 22.32527995   5.74946314 -60.72117614]
# ...
# Warning: root segment  52942 is not mapped (out of the soil domain), this could cause problems with coupling! [10.50197178 -3.80368143 -4.84855922] [10.4307203  -3.85042655 -4.97501842]
# Warning: root segment  52945 is not mapped (out of the soil domain), this could cause problems with coupling! [11.33446011 -2.76347155 -3.33371908] [11.47485463 -2.95010599 -3.77582423]
# Warning: root segment  52946 is not mapped (out of the soil domain), this could cause problems with coupling! [11.47485463 -2.95010599 -3.77582423] [11.67605574 -3.12760397 -4.19773959]
# Warning: root segment  52947 is not mapped (out of the soil domain), this could cause problems with coupling! [11.67605574 -3.12760397 -4.19773959] [11.88514202 -3.30538186 -4.48873435]
# Warning: root segment  52950 is not mapped (out of the soil domain), this could cause problems with coupling! [11.88514202 -3.30538186 -4.48873435] [12.12409716 -3.28094894 -4.92725855]
# Warning: root segment  52951 is not mapped (out of the soil domain), this could cause problems with coupling! [12.12409716 -3.28094894 -4.92725855] [12.2115961  -3.24691756 -5.04742347]
# Warning: root segment  52954 is not mapped (out of the soil domain), this could cause problems with coupling! [11.76564415 -3.02136619 -3.06683751] [11.46662913 -3.25943075 -2.74447857]
# Warning: root segment  52955 is not mapped (out of the soil domain), this could cause problems with coupling! [11.46662913 -3.25943075 -2.74447857] [11.24216247 -3.47994967 -2.35590924]
# Warning: root segment  52956 is not mapped (out of the soil domain), this could cause problems with coupling! [11.24216247 -3.47994967 -2.35590924] [11.03370966 -3.75684067 -2.15621248]
# Warning: root segment  52959 is not mapped (out of the soil domain), this could cause problems with coupling! [11.03370966 -3.75684067 -2.15621248] [10.71776201 -3.9916133  -1.84789625]
# Warning: root segment  52960 is not mapped (out of the soil domain), this could cause problems with coupling! [10.71776201 -3.9916133  -1.84789625] [10.64290626 -4.06645449 -1.73812731]
# Warning: root segment  52963 is not mapped (out of the soil domain), this could cause problems with coupling! [12.20153457 -3.37785525 -2.98564567] [11.75350132 -3.54953466 -3.12633111]
# Warning: root segment  52964 is not mapped (out of the soil domain), this could cause problems with coupling! [11.75350132 -3.54953466 -3.12633111] [11.88876276 -3.98283422 -3.33598758]
# Warning: root segment  52965 is not mapped (out of the soil domain), this could cause problems with coupling! [11.88876276 -3.98283422 -3.33598758] [12.06849529 -4.30958719 -3.48065519]
# Warning: root segment  52968 is not mapped (out of the soil domain), this could cause problems with coupling! [12.06849529 -4.30958719 -3.48065519] [12.20618261 -4.78380642 -3.55913013]
# Warning: root segment  52969 is not mapped (out of the soil domain), this could cause problems with coupling! [12.20618261 -4.78380642 -3.55913013] [12.25990924 -4.92408929 -3.58535936]
# Warning: root segment  52972 is not mapped (out of the soil domain), this could cause problems with coupling! [12.61590323 -3.74896989 -2.86558453] [12.74505101 -3.80649186 -3.34518027]
# Warning: root segment  52973 is not mapped (out of the soil domain), this could cause problems with coupling! [12.74505101 -3.80649186 -3.34518027] [12.83317401 -3.77049344 -3.83603509]
# Warning: root segment  52974 is not mapped (out of the soil domain), this could cause problems with coupling! [12.83317401 -3.77049344 -3.83603509] [12.79372081 -3.88722158 -4.21658467]
# Warning: root segment  52977 is not mapped (out of the soil domain), this could cause problems with coupling! [12.79372081 -3.88722158 -4.21658467] [12.85526779 -4.20483409 -4.59781199]
# Warning: root segment  52978 is not mapped (out of the soil domain), this could cause problems with coupling! [12.85526779 -4.20483409 -4.59781199] [12.90395381 -4.32213003 -4.68222254]
# Warning: root segment  52981 is not mapped (out of the soil domain), this could cause problems with coupling! [12.9756102  -4.18466059 -2.80983134] [13.37629278 -4.07242097 -2.53260267]
# Warning: root segment  52982 is not mapped (out of the soil domain), this could cause problems with coupling! [13.37629278 -4.07242097 -2.53260267] [13.72222104 -3.9529053  -2.19194208]
# Warning: root segment  52983 is not mapped (out of the soil domain), this could cause problems with coupling! [13.72222104 -3.9529053  -2.19194208] [14.03912181 -3.82132593 -1.98636781]
# Warning: root segment  52986 is not mapped (out of the soil domain), this could cause problems with coupling! [14.03912181 -3.82132593 -1.98636781] [14.39905881 -3.76002829 -1.64477163]
# Warning: root segment  52987 is not mapped (out of the soil domain), this could cause problems with coupling! [14.39905881 -3.76002829 -1.64477163] [14.50985766 -3.74520077 -1.54105294]
# Warning: root segment  52990 is not mapped (out of the soil domain), this could cause problems with coupling! [13.41547539 -4.54354689 -2.84146676] [13.15971416 -4.96612196 -2.7639006 ]
# Warning: root segment  52991 is not mapped (out of the soil domain), this could cause problems with coupling! [13.15971416 -4.96612196 -2.7639006 ] [12.89122268 -5.38717223 -2.78898043]
# Warning: root segment  52992 is not mapped (out of the soil domain), this could cause problems with coupling! [12.89122268 -5.38717223 -2.78898043] [12.68506972 -5.7174057  -2.88088695]
# Warning: root segment  52995 is not mapped (out of the soil domain), this could cause problems with coupling! [12.68506972 -5.7174057  -2.88088695] [12.42495911 -6.12906011 -2.99439076]
# Warning: root segment  52996 is not mapped (out of the soil domain), this could cause problems with coupling! [12.42495911 -6.12906011 -2.99439076] [12.31062774 -6.20336519 -2.92611998]
# Warning: root segment  52999 is not mapped (out of the soil domain), this could cause problems with coupling! [13.90190999 -4.80047157 -2.9816509 ] [13.62989758 -5.16830197 -3.1834182 ]
# Warning: root segment  53000 is not mapped (out of the soil domain), this could cause problems with coupling! [13.62989758 -5.16830197 -3.1834182 ] [13.36948634 -5.54566429 -3.38287664]
# Warning: root segment  53001 is not mapped (out of the soil domain), this could cause problems with coupling! [13.36948634 -5.54566429 -3.38287664] [13.21352797 -5.81486727 -3.63428615]
# Warning: root segment  53004 is not mapped (out of the soil domain), this could cause problems with coupling! [13.21352797 -5.81486727 -3.63428615] [13.00086223 -6.14556583 -3.94317406]
# Warning: root segment  53005 is not mapped (out of the soil domain), this could cause problems with coupling! [13.00086223 -6.14556583 -3.94317406] [12.932873   -6.23991262 -4.0418146 ]
# Warning: root segment  53008 is not mapped (out of the soil domain), this could cause problems with coupling! [14.30672821 -5.06874602 -3.27752764] [14.56941564 -4.68804688 -3.08762376]
# Warning: root segment  53009 is not mapped (out of the soil domain), this could cause problems with coupling! [14.56941564 -4.68804688 -3.08762376] [14.8367194  -4.33566587 -2.85443646]
# Warning: root segment  53010 is not mapped (out of the soil domain), this could cause problems with coupling! [14.8367194  -4.33566587 -2.85443646] [15.15982996 -4.10135142 -2.88082416]
# Warning: root segment  53013 is not mapped (out of the soil domain), this could cause problems with coupling! [15.15982996 -4.10135142 -2.88082416] [15.49898218 -3.76064987 -3.01829494]
# Warning: root segment  53014 is not mapped (out of the soil domain), this could cause problems with coupling! [15.49898218 -3.76064987 -3.01829494] [15.60151117 -3.65354304 -3.05392838]
# Warning: root segment  53017 is not mapped (out of the soil domain), this could cause problems with coupling! [14.67006739 -5.22378067 -3.68728822] [15.05037831 -5.27128159 -3.36618502]
# Warning: root segment  53018 is not mapped (out of the soil domain), this could cause problems with coupling! [15.05037831 -5.27128159 -3.36618502] [15.32951208 -5.39819289 -2.97124469]
# Warning: root segment  53019 is not mapped (out of the soil domain), this could cause problems with coupling! [15.32951208 -5.39819289 -2.97124469] [15.63824884 -5.21934251 -2.79042945]
# Warning: root segment  53022 is not mapped (out of the soil domain), this could cause problems with coupling! [15.63824884 -5.21934251 -2.79042945] [15.95342231 -5.22963376 -2.40240912]
# Warning: root segment  53023 is not mapped (out of the soil domain), this could cause problems with coupling! [15.95342231 -5.22963376 -2.40240912] [16.03725368 -5.18920896 -2.28161201]
# Warning: root segment  53026 is not mapped (out of the soil domain), this could cause problems with coupling! [15.03885984 -5.39195138 -4.08666625] [14.9298779  -5.87944868 -4.0650025 ]
# Warning: root segment  53027 is not mapped (out of the soil domain), this could cause problems with coupling! [14.9298779  -5.87944868 -4.0650025 ] [14.79390743 -6.35291595 -3.97932418]
# Warning: root segment  53028 is not mapped (out of the soil domain), this could cause problems with coupling! [14.79390743 -6.35291595 -3.97932418] [14.79201157 -6.74368391 -3.89390283]
# Warning: root segment  53030 is not mapped (out of the soil domain), this could cause problems with coupling! [14.79201157 -6.74368391 -3.89390283] [14.85047819 -7.23703092 -3.95038629]
# Warning: root segment  53031 is not mapped (out of the soil domain), this could cause problems with coupling! [14.85047819 -7.23703092 -3.95038629] [14.79932396 -7.37343413 -3.90531728]
# Warning: root segment  53034 is not mapped (out of the soil domain), this could cause problems with coupling! [15.44821494 -5.5211785  -4.46044939] [15.66335262 -5.88523321 -4.19365369]
# Warning: root segment  53035 is not mapped (out of the soil domain), this could cause problems with coupling! [15.66335262 -5.88523321 -4.19365369] [15.98542345 -6.26692274 -4.1694983 ]
# Warning: root segment  53036 is not mapped (out of the soil domain), this could cause problems with coupling! [15.98542345 -6.26692274 -4.1694983 ] [16.20891638 -6.58497617 -4.075196  ]
# Warning: root segment  53037 is not mapped (out of the soil domain), this could cause problems with coupling! [16.20891638 -6.58497617 -4.075196  ] [16.36054211 -6.81176277 -3.99716613]
# Warning: root segment  53040 is not mapped (out of the soil domain), this could cause problems with coupling! [15.75710426 -5.73024569 -4.89038382] [16.09538501 -5.78820786 -4.52678167]
# Warning: root segment  53041 is not mapped (out of the soil domain), this could cause problems with coupling! [16.09538501 -5.78820786 -4.52678167] [16.53488872 -5.77670016 -4.28865552]
# Warning: root segment  53042 is not mapped (out of the soil domain), this could cause problems with coupling! [16.53488872 -5.77670016 -4.28865552] [16.54813733 -5.77622795 -4.28116972]
# Warning: root segment  53045 is not mapped (out of the soil domain), this could cause problems with coupling! [16.06713316 -5.84389531 -5.35269512] [16.2014777  -5.52528807 -5.37808618]
# Warning: root segment  53257 is not mapped (out of the soil domain), this could cause problems with coupling! [-9.97871446 -7.17736415 -9.89381261] [-10.36947823  -7.09610098  -9.86735571]
# Warning: root segment  53260 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.36947823  -7.09610098  -9.86735571] [-10.85841663  -7.02633207  -9.78943562]
# Warning: root segment  53261 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.85841663  -7.02633207  -9.78943562] [-11.00182027  -7.00811009  -9.74088499]
# Warning: root segment  53275 is not mapped (out of the soil domain), this could cause problems with coupling! [ -9.96012417  -7.68401443 -11.11983046] [-10.18755927  -7.50899668 -11.39847371]
# Warning: root segment  53278 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.18755927  -7.50899668 -11.39847371] [-10.59169392  -7.26481981 -11.56295119]
# Warning: root segment  53279 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.59169392  -7.26481981 -11.56295119] [-10.70551851  -7.18652626 -11.62751038]
# Warning: root segment  53283 is not mapped (out of the soil domain), this could cause problems with coupling! [ -9.83393254  -8.37340898 -10.92884463] [-10.31623457  -8.34355836 -10.80041685]
# Warning: root segment  53284 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.31623457  -8.34355836 -10.80041685] [-10.52876194  -8.34493698 -10.46155077]
# Warning: root segment  53287 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.52876194  -8.34493698 -10.46155077] [-10.81727307  -8.28455904 -10.05767476]
# Warning: root segment  53288 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.81727307  -8.28455904 -10.05767476] [-10.89907184  -8.16313198 -10.01503395]
# Warning: root segment  53292 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.04342538  -8.64659969 -11.21993168] [-10.38531464  -8.39525039 -10.95547892]
# Warning: root segment  53293 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.38531464  -8.39525039 -10.95547892] [-10.73266532  -8.45517245 -10.7663841 ]
# Warning: root segment  53295 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.73266532  -8.45517245 -10.7663841 ] [-11.20312817  -8.53828303 -10.61888041]
# Warning: root segment  53296 is not mapped (out of the soil domain), this could cause problems with coupling! [-11.20312817  -8.53828303 -10.61888041] [-11.34243415  -8.59815277 -10.60265502]
# Warning: root segment  53299 is not mapped (out of the soil domain), this could cause problems with coupling! [ -9.95469428  -9.28668758 -11.71433582] [-10.23811579  -8.97155297 -11.97959498]
# Warning: root segment  53300 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.23811579  -8.97155297 -11.97959498] [-10.57693348  -8.83490063 -12.320958  ]
# Warning: root segment  53301 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.57693348  -8.83490063 -12.320958  ] [-10.68585804  -8.5128984  -12.53178969]
# Warning: root segment  53302 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.68585804  -8.5128984  -12.53178969] [-10.74389076  -8.41939582 -12.61682251]
# Warning: root segment  53305 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.21346964  -9.61760757 -12.09803562] [-10.15810961  -9.32124615 -12.49691553]
# Warning: root segment  53306 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.15810961  -9.32124615 -12.49691553] [-10.04739584  -9.06487128 -12.74047886]
# Warning: root segment  53309 is not mapped (out of the soil domain), this could cause problems with coupling! [-10.52656344  -9.95982261 -12.42703922] [-10.53984329 -10.03472294 -12.23987536]
# Warning: root segment  53514 is not mapped (out of the soil domain), this could cause problems with coupling! [ 9.95167821 -7.05282116 -1.86403143] [10.35690322 -6.84470954 -2.07014363]
# Warning: root segment  53515 is not mapped (out of the soil domain), this could cause problems with coupling! [10.35690322 -6.84470954 -2.07014363] [10.48199617 -6.79167239 -2.1393724 ]
# Warning: root segment  53531 is not mapped (out of the soil domain), this could cause problems with coupling! [10.18133849 -7.41112572 -0.27279616] [10.41012733 -7.51826927 -0.70427725]
# Warning: root segment  53532 is not mapped (out of the soil domain), this could cause problems with coupling! [10.41012733 -7.51826927 -0.70427725] [10.46507387 -7.56754582 -0.91775829]
# Warning: root segment  53535 is not mapped (out of the soil domain), this could cause problems with coupling! [10.6718528  -7.3708713  -0.01250624] [10.69993008 -7.338814   -0.05089943]

# %%
""" Numerical solution """
start_time = timeit.default_timer()
t = 0. # current simulation time [days]
x_, y_ = [], [] # time, actual transpiration
N = round(sim_time / dt) # number of time steps
area = (plant.maxBound.x - plant.minBound.x) * (plant.maxBound.y - plant.minBound.y)  # [cm2]; horizontal cross section of soil domain --> convert volumetric flux per plant <--> depth unit

for i in range(0, N): 

    h_bs = s.getSolutionHead() # soil matric potential per cell
    h_bs = np.array(plant.matric2total(h_bs)) # convert matric to total potential; h_bs: 1D array of soil potential per cell

    start_time_ao = timeit.default_timer()

    hm.update(rs_age + sim_time) # update interal hydraulics to current plant age (in days)

    # Alpha: root system averaged stress factor
    # krs, _ = hm.get_krs(rs_age + sim_time)  # [cm2/day] (could be precomputed for static case)
    krs = hm.krs # whole root axial conductance [cm3/day]
    krs = krs / area # convert to per area conductance [cm/day]
    # --> how easily the entire root system can supply water per unit pressure difference, normalized per unit ground area

    k_srs = hm.get_soil_rootsystem_conductance(rs_age + sim_time, h_bs, wilting_point, sp) # array of soil-root conductances per soil cell [cm/day] 
    # k_srs: how easily each local soil-root interface can supply water per unit pressure difference, normalized per unit ground area
    h_bs_diff = h_bs - np.ones(h_bs.shape) * wilting_point
    alpha = np.multiply(k_srs, h_bs_diff) / (-krs * wilting_point)  # [1]; dimensionless stress factor

    # Omega: root system averaged stress factor
    # suf_ = hm.get_suf(rs_age + sim_time)
    suf_ = hm.suf # array of soil-root uptake fractions per soil cell [1]
    suf = peri.aggregate(suf_[0,:]) # aggregate to soil grid --> per cell weighted sum
    alphaSUF = np.multiply(alpha, suf) # weigh geometrical SUF by local stress factor alpha
    omega = np.nansum(alphaSUF)  # note that nan are treated as 0
    # --> system level stress factor; how much supply capacity is left in the entire root system under current conditions; small = stressed

    # Omega_c: critical stress factor
    tp = trans * sinusoidal(t) / area  # potential tranpiration per unit ground area [cm3 day-1] -> [cm day-1]
    # print("tp", tp)
    omega_c = tp / (-wilting_point * krs) # critical stress level required to meet potential transpiration; larger tp raises omega_c

    # Sink, stressed
    q_s = alphaSUF * tp / omega_c # uptake proportional to alphaSUF scaled to potential demand

    # Sink, unstressed
    denumerator = np.multiply(h_bs_diff, np.nansum(np.divide(alphaSUF, h_bs_diff)))
    
    q_us = alphaSUF * tp / omega_c - np.divide(alphaSUF, denumerator) * (omega / omega_c - 1) * tp # total uptake equals tp; corrected to reflect local availability

    if omega < omega_c:
        print("stressed")
        q = q_s
    else:
        print("unstressed")
        q = q_us

    start_time_soil = timeit.default_timer()

    fluxes = make_source(q, area) # convert per cell sink to dict {cell_index: -q_i * area}
    s.setSource(fluxes) # set source term in soil model
    s.solve(dt) 

    final_time = timeit.default_timer()

    x_.append(t)
    y_.append(-np.nansum(q) * area) 

    n = round(float(i) / float(N) * 100.)  
    print(
        f"[{'*' * n}{' ' * (100 - n)}] | "
        f"potential {tp * area:.2f} | actual {np.nansum(q) * area:.2f} | [{np.min(h_bs):.2f}, {np.max(h_bs):.2f}] cm soil at {s.simTime} days"
    )

    t += dt  # [day]

print (f"Coupled benchmark solved in {timeit.default_timer() - start_time} s")
# Out:
# /home/jhack/phd/CPlantBox/src/functional/Perirhizal.py:105: RuntimeWarning: divide by zero encountered in divide
#   r_phriz = np.divide(1., np.sqrt(np.pi * rld))  # outer perirhizal radii per layer [cm]
# /home/jhack/phd/CPlantBox/src/functional/Perirhizal.py:108: RuntimeWarning: invalid value encountered in add
#   b = np.divide(2 * (rho2 - np.ones(rho2.shape)) , np.ones(rho2.shape) - 0.53 * 0.53 * rho2 + 2 * rho2 * (np.log(rho) + np.log(0.53)))  # [1], see Eqn [8]
# /tmp/ipykernel_315722/2369406736.py:42: RuntimeWarning: invalid value encountered in divide
#   q_s = alphaSUF * tp / omega_c # uptake proportional to alphaSUF scaled to potential demand
# /tmp/ipykernel_315722/2369406736.py:47: RuntimeWarning: invalid value encountered in divide
#   q_us = alphaSUF * tp / omega_c - np.divide(alphaSUF, denumerator) * (omega / omega_c - 1) * tp # total uptake equals tp; corrected to reflect local availability
# /tmp/ipykernel_315722/2369406736.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   q_us = alphaSUF * tp / omega_c - np.divide(alphaSUF, denumerator) * (omega / omega_c - 1) * tp # total uptake equals tp; corrected to reflect local availability
# /tmp/ipykernel_315722/2369406736.py:47: RuntimeWarning: invalid value encountered in multiply
#   q_us = alphaSUF * tp / omega_c - np.divide(alphaSUF, denumerator) * (omega / omega_c - 1) * tp # total uptake equals tp; corrected to reflect local availability
# unstressed
# [                                                                                                    ] | potential 0.00 | actual 0.00 | [-510.70, -503.00] cm soil at 0.041666666666666664 days
# unstressed
# [*                                                                                                   ] | potential 20.44 | actual 20.44 | [-510.82, -502.54] cm soil at 0.08333333333333333 days
# unstressed
# [*                                                                                                   ] | potential 80.38 | actual 80.38 | [-512.52, -502.21] cm soil at 0.125 days
# unstressed
# [**                                                                                                  ] | potential 175.74 | actual 175.74 | [-522.43, -501.95] cm soil at 0.16666666666666666 days
# stressed
# [**                                                                                                  ] | potential 300.00 | actual 275.35 | [-544.06, -501.72] cm soil at 0.20833333333333334 days
# stressed
# [***                                                                                                 ] | potential 444.71 | actual 274.52 | [-578.22, -501.52] cm soil at 0.25 days
# stressed
# [****                                                                                                ] | potential 600.00 | actual 273.69 | [-611.12, -501.33] cm soil at 0.2916666666666667 days
# stressed
# [****                                                                                                ] | potential 755.29 | actual 272.84 | [-643.53, -501.16] cm soil at 0.3333333333333333 days
# stressed
# [*****                                                                                               ] | potential 900.00 | actual 271.98 | [-675.71, -501.00] cm soil at 0.375 days
# stressed
# [*****                                                                                               ] | potential 1024.26 | actual 271.09 | [-708.20, -500.85] cm soil at 0.4166666666666667 days
# stressed
# [******                                                                                              ] | potential 1119.62 | actual 270.18 | [-741.34, -500.71] cm soil at 0.4583333333333333 days
# stressed
# [*******                                                                                             ] | potential 1179.56 | actual 269.25 | [-775.25, -500.58] cm soil at 0.5 days
# stressed
# [*******                                                                                             ] | potential 1200.00 | actual 268.28 | [-810.23, -500.45] cm soil at 0.5416666666666666 days
# stressed
# [********                                                                                            ] | potential 1179.56 | actual 267.28 | [-846.32, -500.33] cm soil at 0.5833333333333334 days
# stressed
# [********                                                                                            ] | potential 1119.62 | actual 266.24 | [-883.68, -500.21] cm soil at 0.625 days
# stressed
# [*********                                                                                           ] | potential 1024.26 | actual 265.17 | [-922.43, -500.09] cm soil at 0.6666666666666666 days
# stressed
# [**********                                                                                          ] | potential 900.00 | actual 264.06 | [-962.69, -499.98] cm soil at 0.7083333333333334 days
# stressed
# [**********                                                                                          ] | potential 755.29 | actual 262.90 | [-1004.59, -499.88] cm soil at 0.75 days
# stressed
# [***********                                                                                         ] | potential 600.00 | actual 261.71 | [-1048.20, -499.77] cm soil at 0.7916666666666666 days
# stressed
# [***********                                                                                         ] | potential 444.71 | actual 260.47 | [-1093.67, -499.67] cm soil at 0.8333333333333334 days
# stressed
# [************                                                                                        ] | potential 300.00 | actual 259.18 | [-1141.03, -499.57] cm soil at 0.875 days
# unstressed
# [************                                                                                        ] | potential 175.74 | actual 175.74 | [-1190.49, -499.47] cm soil at 0.9166666666666666 days
# unstressed
# [*************                                                                                       ] | potential 80.38 | actual 80.38 | [-1211.16, -499.38] cm soil at 0.9583333333333334 days
# unstressed
# [**************                                                                                      ] | potential 20.44 | actual 20.44 | [-1198.78, -499.29] cm soil at 1.0 days
# unstressed
# [**************                                                                                      ] | potential 0.00 | actual 0.00 | [-1169.04, -499.20] cm soil at 1.0416666666666667 days
# unstressed
# [***************                                                                                     ] | potential 20.44 | actual 20.44 | [-1138.85, -499.11] cm soil at 1.0833333333333333 days
# unstressed
# [***************                                                                                     ] | potential 80.38 | actual 80.38 | [-1118.26, -499.02] cm soil at 1.125 days
# unstressed
# [****************                                                                                    ] | potential 175.74 | actual 175.74 | [-1120.68, -498.94] cm soil at 1.1666666666666667 days
# stressed
# [*****************                                                                                   ] | potential 300.00 | actual 257.10 | [-1156.53, -498.85] cm soil at 1.2083333333333333 days
# stressed
# [*****************                                                                                   ] | potential 444.71 | actual 255.50 | [-1222.47, -498.77] cm soil at 1.25 days
# stressed
# [******************                                                                                  ] | potential 600.00 | actual 253.86 | [-1288.75, -498.69] cm soil at 1.2916666666666667 days
# stressed
# [******************                                                                                  ] | potential 755.29 | actual 252.19 | [-1356.20, -498.61] cm soil at 1.3333333333333333 days
# stressed
# [*******************                                                                                 ] | potential 900.00 | actual 250.47 | [-1425.45, -498.53] cm soil at 1.375 days
# stressed
# [********************                                                                                ] | potential 1024.26 | actual 248.71 | [-1496.65, -498.46] cm soil at 1.4166666666666667 days
# stressed
# [********************                                                                                ] | potential 1119.62 | actual 246.90 | [-1570.06, -498.38] cm soil at 1.4583333333333333 days
# stressed
# [*********************                                                                               ] | potential 1179.56 | actual 245.05 | [-1645.88, -498.31] cm soil at 1.5 days
# stressed
# [*********************                                                                               ] | potential 1200.00 | actual 243.14 | [-1724.32, -498.23] cm soil at 1.5416666666666667 days
# stressed
# [**********************                                                                              ] | potential 1179.56 | actual 241.19 | [-1805.39, -498.16] cm soil at 1.5833333333333333 days
# stressed
# [***********************                                                                             ] | potential 1119.62 | actual 239.20 | [-1889.35, -498.09] cm soil at 1.625 days
# stressed
# [***********************                                                                             ] | potential 1024.26 | actual 237.16 | [-1976.06, -498.02] cm soil at 1.6666666666666667 days
# stressed
# [************************                                                                            ] | potential 900.00 | actual 235.08 | [-2065.75, -497.95] cm soil at 1.7083333333333333 days
# stressed
# [************************                                                                            ] | potential 755.29 | actual 232.96 | [-2158.50, -497.88] cm soil at 1.75 days
# stressed
# [*************************                                                                           ] | potential 600.00 | actual 230.80 | [-2254.39, -497.81] cm soil at 1.7916666666666667 days
# stressed
# [**************************                                                                          ] | potential 444.71 | actual 228.60 | [-2353.37, -497.74] cm soil at 1.8333333333333333 days
# stressed
# [**************************                                                                          ] | potential 300.00 | actual 226.38 | [-2455.29, -497.68] cm soil at 1.875 days
# unstressed
# [***************************                                                                         ] | potential 175.74 | actual 175.74 | [-2560.38, -497.61] cm soil at 1.9166666666666667 days
# unstressed
# [***************************                                                                         ] | potential 80.38 | actual 80.38 | [-2625.36, -497.55] cm soil at 1.9583333333333333 days
# unstressed
# [****************************                                                                        ] | potential 20.44 | actual 20.44 | [-2609.57, -497.48] cm soil at 2.0 days
# unstressed
# [*****************************                                                                       ] | potential 0.00 | actual 0.00 | [-2545.70, -497.42] cm soil at 2.0416666666666665 days
# unstressed
# [*****************************                                                                       ] | potential 20.44 | actual 20.44 | [-2483.05, -497.36] cm soil at 2.0833333333333335 days
# unstressed
# [******************************                                                                      ] | potential 80.38 | actual 80.38 | [-2428.46, -497.29] cm soil at 2.125 days
# unstressed
# [******************************                                                                      ] | potential 175.74 | actual 175.74 | [-2425.81, -497.23] cm soil at 2.1666666666666665 days
# stressed
# [*******************************                                                                     ] | potential 300.00 | actual 222.81 | [-2503.62, -497.17] cm soil at 2.2083333333333335 days
# stressed
# [********************************                                                                    ] | potential 444.71 | actual 220.28 | [-2624.91, -497.11] cm soil at 2.25 days
# stressed
# [********************************                                                                    ] | potential 600.00 | actual 217.76 | [-2749.13, -497.05] cm soil at 2.2916666666666665 days
# stressed
# [*********************************                                                                   ] | potential 755.29 | actual 215.24 | [-2876.00, -496.99] cm soil at 2.3333333333333335 days
# stressed
# [*********************************                                                                   ] | potential 900.00 | actual 212.72 | [-3005.15, -496.93] cm soil at 2.375 days
# stressed
# [**********************************                                                                  ] | potential 1024.26 | actual 210.21 | [-3136.52, -496.87] cm soil at 2.4166666666666665 days
# stressed
# [***********************************                                                                 ] | potential 1119.62 | actual 207.71 | [-3270.13, -496.82] cm soil at 2.4583333333333335 days
# stressed
# [***********************************                                                                 ] | potential 1179.56 | actual 205.23 | [-3405.61, -496.76] cm soil at 2.5 days
# stressed
# [************************************                                                                ] | potential 1200.00 | actual 202.76 | [-3543.06, -496.70] cm soil at 2.5416666666666665 days
# stressed
# [************************************                                                                ] | potential 1179.56 | actual 200.32 | [-3681.72, -496.65] cm soil at 2.5833333333333335 days
# stressed
# [*************************************                                                               ] | potential 1119.62 | actual 197.89 | [-3821.99, -496.59] cm soil at 2.625 days
# stressed
# [**************************************                                                              ] | potential 1024.26 | actual 195.50 | [-3963.50, -496.54] cm soil at 2.6666666666666665 days
# stressed
# [**************************************                                                              ] | potential 900.00 | actual 193.14 | [-4106.09, -496.48] cm soil at 2.7083333333333335 days
# stressed
# [***************************************                                                             ] | potential 755.29 | actual 190.80 | [-4249.57, -496.43] cm soil at 2.75 days
# stressed
# [***************************************                                                             ] | potential 600.00 | actual 188.50 | [-4393.81, -496.37] cm soil at 2.7916666666666665 days
# stressed
# [****************************************                                                            ] | potential 444.71 | actual 186.24 | [-4538.56, -496.32] cm soil at 2.8333333333333335 days
# stressed
# [****************************************                                                            ] | potential 300.00 | actual 184.01 | [-4683.81, -496.27] cm soil at 2.875 days
# unstressed
# [*****************************************                                                           ] | potential 175.74 | actual 175.74 | [-4829.18, -496.21] cm soil at 2.9166666666666665 days
# unstressed
# [******************************************                                                          ] | potential 80.38 | actual 80.38 | [-4965.25, -496.16] cm soil at 2.9583333333333335 days
# unstressed
# [******************************************                                                          ] | potential 20.44 | actual 20.44 | [-4953.45, -496.11] cm soil at 3.0 days
# unstressed
# [*******************************************                                                         ] | potential 0.00 | actual 0.00 | [-4851.48, -496.06] cm soil at 3.0416666666666665 days
# unstressed
# [*******************************************                                                         ] | potential 20.44 | actual 20.44 | [-4774.96, -496.01] cm soil at 3.0833333333333335 days
# unstressed
# [********************************************                                                        ] | potential 80.38 | actual 80.38 | [-4679.62, -495.95] cm soil at 3.125 days
# unstressed
# [*********************************************                                                       ] | potential 175.74 | actual 175.74 | [-4676.84, -495.90] cm soil at 3.1666666666666665 days
# stressed
# [*********************************************                                                       ] | potential 300.00 | actual 179.48 | [-4821.33, -495.85] cm soil at 3.2083333333333335 days
# stressed
# [**********************************************                                                      ] | potential 444.71 | actual 177.19 | [-4975.88, -495.80] cm soil at 3.25 days
# stressed
# [**********************************************                                                      ] | potential 600.00 | actual 174.96 | [-5130.31, -495.75] cm soil at 3.2916666666666665 days
# stressed
# [***********************************************                                                     ] | potential 755.29 | actual 172.79 | [-5284.40, -495.71] cm soil at 3.3333333333333335 days
# stressed
# [************************************************                                                    ] | potential 900.00 | actual 170.67 | [-5438.43, -495.66] cm soil at 3.375 days
# stressed
# [************************************************                                                    ] | potential 1024.26 | actual 168.60 | [-5592.12, -495.61] cm soil at 3.4166666666666665 days
# stressed
# [*************************************************                                                   ] | potential 1119.62 | actual 166.59 | [-5744.52, -495.56] cm soil at 3.4583333333333335 days
# stressed
# [*************************************************                                                   ] | potential 1179.56 | actual 164.63 | [-5896.17, -495.51] cm soil at 3.5 days
# stressed
# [**************************************************                                                  ] | potential 1200.00 | actual 162.71 | [-6046.66, -495.46] cm soil at 3.5416666666666665 days
# stressed
# [***************************************************                                                 ] | potential 1179.56 | actual 160.85 | [-6196.01, -495.42] cm soil at 3.5833333333333335 days
# stressed
# [***************************************************                                                 ] | potential 1119.62 | actual 159.02 | [-6343.90, -495.37] cm soil at 3.625 days
# stressed
# [****************************************************                                                ] | potential 1024.26 | actual 157.25 | [-6490.69, -495.32] cm soil at 3.6666666666666665 days
# stressed
# [****************************************************                                                ] | potential 900.00 | actual 155.52 | [-6635.34, -495.28] cm soil at 3.7083333333333335 days
# stressed
# [*****************************************************                                               ] | potential 755.29 | actual 153.83 | [-6778.47, -495.23] cm soil at 3.75 days
# stressed
# [******************************************************                                              ] | potential 600.00 | actual 152.18 | [-6920.11, -495.19] cm soil at 3.7916666666666665 days
# stressed
# [******************************************************                                              ] | potential 444.71 | actual 150.58 | [-7060.27, -495.14] cm soil at 3.8333333333333335 days
# stressed
# [*******************************************************                                             ] | potential 300.00 | actual 149.01 | [-7198.26, -495.10] cm soil at 3.875 days
# stressed
# [*******************************************************                                             ] | potential 175.74 | actual 147.48 | [-7334.61, -495.05] cm soil at 3.9166666666666665 days
# unstressed
# [********************************************************                                            ] | potential 80.38 | actual 80.38 | [-7469.32, -495.01] cm soil at 3.9583333333333335 days
# unstressed
# [*********************************************************                                           ] | potential 20.44 | actual 20.44 | [-7460.04, -494.96] cm soil at 4.0 days
# unstressed
# [*********************************************************                                           ] | potential 0.00 | actual 0.00 | [-7325.47, -494.92] cm soil at 4.041666666666667 days
# unstressed
# [**********************************************************                                          ] | potential 20.44 | actual 20.44 | [-7259.05, -494.87] cm soil at 4.083333333333333 days
# unstressed
# [**********************************************************                                          ] | potential 80.38 | actual 80.38 | [-7130.10, -494.83] cm soil at 4.125 days
# stressed
# [***********************************************************                                         ] | potential 175.74 | actual 147.29 | [-7129.41, -494.79] cm soil at 4.166666666666667 days
# stressed
# [************************************************************                                        ] | potential 300.00 | actual 145.68 | [-7272.29, -494.74] cm soil at 4.208333333333333 days
# stressed
# [************************************************************                                        ] | potential 444.71 | actual 144.11 | [-7413.66, -494.70] cm soil at 4.25 days
# stressed
# [*************************************************************                                       ] | potential 600.00 | actual 142.59 | [-7553.18, -494.66] cm soil at 4.291666666666667 days
# stressed
# [*************************************************************                                       ] | potential 755.29 | actual 141.11 | [-7691.16, -494.62] cm soil at 4.333333333333333 days
# stressed
# [**************************************************************                                      ] | potential 900.00 | actual 139.67 | [-7826.69, -494.58] cm soil at 4.375 days
# stressed
# [**************************************************************                                      ] | potential 1024.26 | actual 138.28 | [-7960.29, -494.53] cm soil at 4.416666666666667 days
# stressed
# [***************************************************************                                     ] | potential 1119.62 | actual 136.91 | [-8092.02, -494.49] cm soil at 4.458333333333333 days
# stressed
# [****************************************************************                                    ] | potential 1179.56 | actual 135.59 | [-8221.64, -494.45] cm soil at 4.5 days
# stressed
# [****************************************************************                                    ] | potential 1200.00 | actual 134.30 | [-8349.22, -494.41] cm soil at 4.541666666666667 days
# stressed
# [*****************************************************************                                   ] | potential 1179.56 | actual 133.04 | [-8474.60, -494.37] cm soil at 4.583333333333333 days
# stressed
# [*****************************************************************                                   ] | potential 1119.62 | actual 131.81 | [-8598.03, -494.33] cm soil at 4.625 days
# stressed
# [******************************************************************                                  ] | potential 1024.26 | actual 130.61 | [-8719.00, -494.29] cm soil at 4.666666666666667 days
# stressed
# [*******************************************************************                                 ] | potential 900.00 | actual 129.44 | [-8837.97, -494.25] cm soil at 4.708333333333333 days
# stressed
# [*******************************************************************                                 ] | potential 755.29 | actual 128.30 | [-8954.81, -494.21] cm soil at 4.75 days
# stressed
# [********************************************************************                                ] | potential 600.00 | actual 127.18 | [-9069.52, -494.17] cm soil at 4.791666666666667 days
# stressed
# [********************************************************************                                ] | potential 444.71 | actual 126.09 | [-9182.15, -494.13] cm soil at 4.833333333333333 days
# stressed
# [*********************************************************************                               ] | potential 300.00 | actual 125.03 | [-9292.64, -494.09] cm soil at 4.875 days
# stressed
# [**********************************************************************                              ] | potential 175.74 | actual 123.99 | [-9401.15, -494.05] cm soil at 4.916666666666667 days
# unstressed
# [**********************************************************************                              ] | potential 80.38 | actual 80.38 | [-9507.54, -494.01] cm soil at 4.958333333333333 days
# unstressed
# [***********************************************************************                             ] | potential 20.44 | actual 20.44 | [-9501.28, -493.98] cm soil at 5.0 days
# unstressed
# [***********************************************************************                             ] | potential 0.00 | actual 0.00 | [-9343.04, -493.94] cm soil at 5.041666666666667 days
# unstressed
# [************************************************************************                            ] | potential 20.44 | actual 20.44 | [-9291.67, -493.90] cm soil at 5.083333333333333 days
# unstressed
# [*************************************************************************                           ] | potential 80.38 | actual 80.38 | [-9139.21, -493.86] cm soil at 5.125 days
# stressed
# [*************************************************************************                           ] | potential 175.74 | actual 123.78 | [-9142.48, -493.83] cm soil at 5.166666666666667 days
# stressed
# [**************************************************************************                          ] | potential 300.00 | actual 122.69 | [-9258.67, -493.79] cm soil at 5.208333333333333 days
# stressed
# [**************************************************************************                          ] | potential 444.71 | actual 121.62 | [-9372.50, -493.75] cm soil at 5.25 days
# stressed
# [***************************************************************************                         ] | potential 600.00 | actual 120.59 | [-9484.33, -493.71] cm soil at 5.291666666666667 days
# stressed
# [****************************************************************************                        ] | potential 755.29 | actual 119.58 | [-9594.16, -493.68] cm soil at 5.333333333333333 days
# stressed
# [****************************************************************************                        ] | potential 900.00 | actual 118.59 | [-9701.67, -493.64] cm soil at 5.375 days
# stressed
# [*****************************************************************************                       ] | potential 1024.26 | actual 117.63 | [-9807.18, -493.61] cm soil at 5.416666666666667 days
# stressed
# [*****************************************************************************                       ] | potential 1119.62 | actual 116.68 | [-9910.82, -493.57] cm soil at 5.458333333333333 days
# stressed
# [******************************************************************************                      ] | potential 1179.56 | actual 115.77 | [-10011.97, -493.53] cm soil at 5.5 days
# stressed
# [*******************************************************************************                     ] | potential 1200.00 | actual 114.87 | [-10111.17, -493.50] cm soil at 5.541666666666667 days
# stressed
# [*******************************************************************************                     ] | potential 1179.56 | actual 113.99 | [-10208.31, -493.46] cm soil at 5.583333333333333 days
# stressed
# [********************************************************************************                    ] | potential 1119.62 | actual 113.13 | [-10303.55, -493.43] cm soil at 5.625 days
# stressed
# [********************************************************************************                    ] | potential 1024.26 | actual 112.29 | [-10396.77, -493.39] cm soil at 5.666666666666667 days
# stressed
# [*********************************************************************************                   ] | potential 900.00 | actual 111.46 | [-10488.10, -493.36] cm soil at 5.708333333333333 days
# stressed
# [**********************************************************************************                  ] | potential 755.29 | actual 110.66 | [-10577.44, -493.33] cm soil at 5.75 days
# stressed
# [**********************************************************************************                  ] | potential 600.00 | actual 109.87 | [-10664.77, -493.29] cm soil at 5.791666666666667 days
# stressed
# [***********************************************************************************                 ] | potential 444.71 | actual 109.09 | [-10750.27, -493.26] cm soil at 5.833333333333333 days
# stressed
# [***********************************************************************************                 ] | potential 300.00 | actual 108.33 | [-10834.05, -493.22] cm soil at 5.875 days
# stressed
# [************************************************************************************                ] | potential 175.74 | actual 107.59 | [-10916.03, -493.19] cm soil at 5.916666666666667 days
# unstressed
# [*************************************************************************************               ] | potential 80.38 | actual 80.38 | [-10996.28, -493.16] cm soil at 5.958333333333333 days
# unstressed
# [*************************************************************************************               ] | potential 20.44 | actual 20.44 | [-10996.79, -493.12] cm soil at 6.0 days
# unstressed
# [**************************************************************************************              ] | potential 0.00 | actual 0.00 | [-10824.31, -493.09] cm soil at 6.041666666666667 days
# unstressed
# [**************************************************************************************              ] | potential 20.44 | actual 20.44 | [-10785.63, -493.06] cm soil at 6.083333333333333 days
# unstressed
# [***************************************************************************************             ] | potential 80.38 | actual 80.38 | [-10619.18, -493.03] cm soil at 6.125 days
# stressed
# [****************************************************************************************            ] | potential 175.74 | actual 107.35 | [-10629.86, -492.99] cm soil at 6.166666666666667 days
# stressed
# [****************************************************************************************            ] | potential 300.00 | actual 106.57 | [-10720.41, -492.96] cm soil at 6.208333333333333 days
# stressed
# [*****************************************************************************************           ] | potential 444.71 | actual 105.81 | [-10808.99, -492.93] cm soil at 6.25 days
# stressed
# [*****************************************************************************************           ] | potential 600.00 | actual 105.06 | [-10895.71, -492.90] cm soil at 6.291666666666667 days
# stressed
# [******************************************************************************************          ] | potential 755.29 | actual 104.33 | [-10980.55, -492.87] cm soil at 6.333333333333333 days
# stressed
# [******************************************************************************************          ] | potential 900.00 | actual 103.62 | [-11063.49, -492.83] cm soil at 6.375 days
# stressed
# [*******************************************************************************************         ] | potential 1024.26 | actual 102.92 | [-11144.65, -492.80] cm soil at 6.416666666666667 days
# stressed
# [********************************************************************************************        ] | potential 1119.62 | actual 102.23 | [-11223.86, -492.77] cm soil at 6.458333333333333 days
# stressed
# [********************************************************************************************        ] | potential 1179.56 | actual 101.56 | [-11301.34, -492.74] cm soil at 6.5 days
# stressed
# [*********************************************************************************************       ] | potential 1200.00 | actual 100.90 | [-11377.11, -492.71] cm soil at 6.541666666666667 days
# stressed
# [*********************************************************************************************       ] | potential 1179.56 | actual 100.25 | [-11451.12, -492.68] cm soil at 6.583333333333333 days
# stressed
# [**********************************************************************************************      ] | potential 1119.62 | actual 99.62 | [-11523.58, -492.65] cm soil at 6.625 days
# stressed
# [***********************************************************************************************     ] | potential 1024.26 | actual 99.00 | [-11594.16, -492.62] cm soil at 6.666666666666667 days
# stressed
# [***********************************************************************************************     ] | potential 900.00 | actual 98.38 | [-11663.21, -492.59] cm soil at 6.708333333333333 days
# stressed
# [************************************************************************************************    ] | potential 755.29 | actual 97.78 | [-11730.62, -492.56] cm soil at 6.75 days
# stressed
# [************************************************************************************************    ] | potential 600.00 | actual 97.19 | [-11796.57, -492.53] cm soil at 6.791666666666667 days
# stressed
# [*************************************************************************************************   ] | potential 444.71 | actual 96.61 | [-11860.98, -492.50] cm soil at 6.833333333333333 days
# stressed
# [**************************************************************************************************  ] | potential 300.00 | actual 96.04 | [-11923.97, -492.47] cm soil at 6.875 days
# stressed
# [**************************************************************************************************  ] | potential 175.74 | actual 95.48 | [-11985.42, -492.45] cm soil at 6.916666666666667 days
# unstressed
# [*************************************************************************************************** ] | potential 80.38 | actual 80.38 | [-12045.50, -492.42] cm soil at 6.958333333333333 days
# unstressed
# [*************************************************************************************************** ] | potential 20.44 | actual 20.44 | [-12057.13, -492.39] cm soil at 7.0 days
# Coupled benchmark solved in 169.2596604290011 s

# %%
""" Transpiration over time """
fig, ax1 = plt.subplots()
ax1.plot(x_, trans * sinusoidal(x_), 'k')  # potential transpiration
ax1.plot(x_, -np.array(y_), 'g')  # actual transpiration
ax2 = ax1.twinx()
ax2.plot(x_, np.cumsum(-np.array(y_) * dt), 'c--')  # cumulative transpiratio
ax1.set_xlabel("Time [d]")
ax1.set_ylabel("Transpiration $[mL d^{-1}]$ per plant")
ax1.legend(['Potential', 'Actual', 'Cumulative'], loc = 'upper left')
plt.show()

# %%
vp.plot_roots_and_soil(hm.ms.mappedSegments(), "pressure head", hm.get_hs(h_bs), s, periodic, min_b, max_b, 
                       cell_number, interactiveImage = True)

# %%
depth_array = [cc[2] for cc in s.getCellCenters()]
fig, ax1 = plt.subplots()
ax1.plot(q/np.nansum(q), depth_array,label = "RWU fraction [-]", linewidth=4 )  
ax1.plot(suf, depth_array, label = "SUF [-]")
ax2 = ax1.twiny()
ax2.plot(h_bs, depth_array, label="Soil water potential [cm]",color='g')  
ax1.set_xlabel("Fraction [-]")
ax1.set_ylabel("Depth [cm]")
ax1.legend(bbox_to_anchor=(1.7, 0.75))
ax2.legend(bbox_to_anchor=(1.7, 0.5))
plt.show()
